# %%
import numpy as np

from tqdm import tqdm, trange

import math
import torch
import torch.nn as nn
from torch.optim import Adam
from torch.nn import CrossEntropyLoss
from torch.utils.data import DataLoader

from torchvision.transforms import ToTensor
from torchvision.datasets.mnist import MNIST

np.random.seed(0)
torch.manual_seed(0)

def main():
    # Loading data
    transform = ToTensor()

    train_set = MNIST(root='/content', train=True, download=True, transform=transform)
    test_set = MNIST(root='/content', train=False, download=True, transform=transform)

    train_loader = DataLoader(train_set, shuffle=True, batch_size=128)
    test_loader = DataLoader(test_set, shuffle=False, batch_size=128)

    # Defining model and training options
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print("Using device: ", device, f"({torch.cuda.get_device_name(device)})" if torch.cuda.is_available() else "")
    model = MyViT((1, 28, 28), n_patches=7, n_blocks=2, hidden_d=8, n_heads=2, out_d=10).to(device)
    N_EPOCHS = 5
    LR = 0.005

    # Training loop
    optimizer = Adam(model.parameters(), lr=LR)
    criterion = CrossEntropyLoss()
    for epoch in trange(N_EPOCHS, desc="Training"):
        train_loss = 0.0
        for batch in tqdm(train_loader, desc=f"Epoch {epoch + 1} in training", leave=False):
            x, y = batch
            x, y = x.to(device), y.to(device)
            y_hat = model(x)
            loss = criterion(y_hat, y)

            train_loss += loss.detach().cpu().item() / len(train_loader)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        print(f"Epoch {epoch + 1}/{N_EPOCHS} loss: {train_loss:.2f}")

    # Test loop
    with torch.no_grad():
        correct, total = 0, 0
        test_loss = 0.0
        for batch in tqdm(test_loader, desc="Testing"):
            x, y = batch
            x, y = x.to(device), y.to(device)
            y_hat = model(x)
            loss = criterion(y_hat, y)
            test_loss += loss.detach().cpu().item() / len(test_loader)

            correct += torch.sum(torch.argmax(y_hat, dim=1) == y).detach().cpu().item()
            total += len(x)
        print(f"Test loss: {test_loss:.2f}")
        print(f"Test accuracy: {correct / total * 100:.2f}%")

# %%
# Vision Transformer (ViT) Model
class MyViT(nn.Module):
    def __init__(self, chw, n_patches=7, n_blocks=2, hidden_d=8, n_heads=2, out_d=10):
        super(MyViT, self).__init__()
        self.chw = chw  # (C, H, W)
        self.n_patches = n_patches
        self.n_blocks = n_blocks
        self.n_heads = n_heads
        self.hidden_d = hidden_d

        # Input and patches sizes
        assert chw[1] % n_patches == 0, "Input shape not entirely divisible by number of patches"
        assert chw[2] % n_patches == 0, "Input shape not entirely divisible by number of patches"
        self.patch_size = (chw[1] // n_patches, chw[2] // n_patches)

        # 1) Linear mapper
        self.input_d = int(chw[0] * self.patch_size[0] * self.patch_size[1])
        self.linear_mapper = nn.Linear(self.input_d, self.hidden_d)

        # 2) Learnable classification token
        self.class_token = nn.Parameter(torch.rand(1, self.hidden_d))

        # 3) Positional embedding
        self.register_buffer('positional_embeddings', self.get_positional_embeddings(n_patches ** 2 + 1, hidden_d), persistent=False)

        # 4) Transformer encoder blocks
        self.blocks = nn.ModuleList([MyViTBlock(hidden_d, n_heads) for _ in range(n_blocks)])

        # 5) Classification MLP
        self.mlp = nn.Sequential(
            nn.Linear(self.hidden_d, out_d),
            nn.Softmax(dim=-1)
        )

    def forward(self, images):
        n, c, h, w = images.shape
        patches = self.patchify(images)
        tokens = self.linear_mapper(patches)

        # Add classification token to the tokens
        tokens = torch.cat((self.class_token.expand(n, 1, -1), tokens), dim=1)

        # Add positional embedding
        out = tokens + self.positional_embeddings.repeat(n, 1, 1)

        # Transformer blocks
        for block in self.blocks:
            out = block(out)

        # Get the classification token only
        out = out[:, 0]
        return self.mlp(out)

    def patchify(self, images):
        # Dividing images into patches
        n, c, h, w = images.shape
        patches = images.unfold(2, self.patch_size[0], self.patch_size[0]).unfold(3, self.patch_size[1], self.patch_size[1])
        patches = patches.contiguous().view(n, c, -1, self.patch_size[0] * self.patch_size[1])
        patches = patches.permute(0, 2, 1, 3).reshape(n, -1, self.input_d)
        return patches

    def get_positional_embeddings(self, seq_len, hidden_d):
        pe = torch.zeros(seq_len, hidden_d)
        position = torch.arange(0, seq_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, hidden_d, 2).float() * -(math.log(10000.0) / hidden_d))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        return pe

# Vision Transformer Block
class MyViTBlock(nn.Module):
    def __init__(self, hidden_d, n_heads, mlp_ratio=4):
        super(MyViTBlock, self).__init__()
        self.hidden_d = hidden_d
        self.n_heads = n_heads

        self.norm1 = nn.LayerNorm(hidden_d)
        self.mhsa = MyMSA(hidden_d, n_heads)
        self.norm2 = nn.LayerNorm(hidden_d)
        self.mlp = nn.Sequential(
            nn.Linear(hidden_d, mlp_ratio * hidden_d),
            nn.GELU(),
            nn.Linear(mlp_ratio * hidden_d, hidden_d)
        )

    def forward(self, x):
        out = x + self.mhsa(self.norm1(x))
        out = out + self.mlp(self.norm2(out))
        return out

# Multi-Head Self Attention
class MyMSA(nn.Module):
    def __init__(self, d, n_heads=2):
        super(MyMSA, self).__init__()
        self.d = d
        self.n_heads = n_heads
        assert d % n_heads == 0, f"Can't divide dimension {d} into {n_heads} heads"
        self.d_head = d // n_heads

        self.q_mappings = nn.ModuleList([nn.Linear(self.d_head, self.d_head) for _ in range(self.n_heads)])
        self.k_mappings = nn.ModuleList([nn.Linear(self.d_head, self.d_head) for _ in range(self.n_heads)])
        self.v_mappings = nn.ModuleList([nn.Linear(self.d_head, self.d_head) for _ in range(self.n_heads)])
        self.softmax = nn.Softmax(dim=-1)

    def forward(self, sequences):
        result = []
        for sequence in sequences:
            seq_result = []
            for head in range(self.n_heads):
                q_mapping = self.q_mappings[head]
                k_mapping = self.k_mappings[head]
                v_mapping = self.v_mappings[head]

                seq = sequence[:, head * self.d_head: (head + 1) * self.d_head]
                q, k, v = q_mapping(seq), k_mapping(seq), v_mapping(seq)

                attention = self.softmax(q @ k.T / (self.d_head ** 0.5))
                seq_result.append(attention @ v)
            result.append(torch.hstack(seq_result))
        return torch.cat([torch.unsqueeze(r, dim=0) for r in result])

# %%
from torch.optim import Adam
from torch.nn import CrossEntropyLoss
from torch.utils.data import DataLoader
from torchvision.transforms import ToTensor
from torchvision.datasets import MNIST
from tqdm import tqdm, trange

# Main function for training and testing
def main():
    # Loading data
    transform = ToTensor()

    train_set = MNIST(root='/content', train=True, download=True, transform=transform)
    test_set = MNIST(root='/content', train=False, download=True, transform=transform)

    train_loader = DataLoader(train_set, shuffle=True, batch_size=128)
    test_loader = DataLoader(test_set, shuffle=False, batch_size=128)

    # Define model and training options
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print("Using device: ", device, f"({torch.cuda.get_device_name(device)})" if torch.cuda.is_available() else "")

    # Initialize the ViT model with the correct input dimensions and parameters
    model = MyViT((1, 28, 28), n_patches=7, n_blocks=2, hidden_d=8, n_heads=2, out_d=10).to(device)

    # Hyperparameters
    N_EPOCHS = 5
    LR = 0.005

    # Loss function and optimizer
    optimizer = Adam(model.parameters(), lr=LR)
    criterion = CrossEntropyLoss()

    # Training loop
    for epoch in trange(N_EPOCHS, desc="Training"):
        train_loss = 0.0
        for batch in tqdm(train_loader, desc=f"Epoch {epoch + 1} in training", leave=False):
            x, y = batch
            x, y = x.to(device), y.to(device)

            # Forward pass
            y_hat = model(x)
            loss = criterion(y_hat, y)

            # Track training loss
            train_loss += loss.detach().cpu().item() / len(train_loader)

            # Backward pass
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        print(f"Epoch {epoch + 1}/{N_EPOCHS} - Training loss: {train_loss:.2f}")

    # Testing loop
    with torch.no_grad():
        correct, total = 0, 0
        test_loss = 0.0
        for batch in tqdm(test_loader, desc="Testing"):
            x, y = batch
            x, y = x.to(device), y.to(device)

            # Forward pass for test data
            y_hat = model(x)
            loss = criterion(y_hat, y)
            test_loss += loss.detach().cpu().item() / len(test_loader)

            # Track correct predictions
            correct += torch.sum(torch.argmax(y_hat, dim=1) == y).detach().cpu().item()
            total += len(x)

        print(f"Test loss: {test_loss:.2f}")
        print(f"Test accuracy: {correct / total * 100:.2f}%")

# Call main function to train and evaluate
if __name__ == '__main__':
    main()
# Out:
# Using device:  cpu
# Training:   0%|          | 0/5 [00:00<?, ?it/s]
# Epoch 1 in training:   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch 1 in training:   0%|          | 1/469 [00:00<02:51,  2.73it/s]
# Epoch 1 in training:   0%|          | 2/469 [00:00<02:50,  2.74it/s]
# Epoch 1 in training:   1%|          | 3/469 [00:01<03:09,  2.45it/s]
# Epoch 1 in training:   1%|          | 4/469 [00:01<03:13,  2.40it/s]
# Epoch 1 in training:   1%|          | 5/469 [00:02<03:13,  2.40it/s]
# Epoch 1 in training:   1%|▏         | 6/469 [00:02<03:17,  2.35it/s]
# Epoch 1 in training:   1%|▏         | 7/469 [00:02<03:27,  2.23it/s]
# Epoch 1 in training:   2%|▏         | 8/469 [00:03<03:23,  2.27it/s]
# Epoch 1 in training:   2%|▏         | 9/469 [00:03<03:05,  2.47it/s]
# Epoch 1 in training:   2%|▏         | 10/469 [00:04<02:51,  2.67it/s]
# Epoch 1 in training:   2%|▏         | 11/469 [00:04<02:49,  2.69it/s]
# Epoch 1 in training:   3%|▎         | 12/469 [00:04<02:41,  2.82it/s]
# Epoch 1 in training:   3%|▎         | 13/469 [00:05<02:40,  2.85it/s]
# Epoch 1 in training:   3%|▎         | 14/469 [00:05<02:54,  2.61it/s]
# Epoch 1 in training:   3%|▎         | 15/469 [00:06<03:18,  2.29it/s]
# Epoch 1 in training:   3%|▎         | 16/469 [00:06<03:15,  2.31it/s]
# Epoch 1 in training:   4%|▎         | 17/469 [00:06<03:00,  2.51it/s]
# Epoch 1 in training:   4%|▍         | 18/469 [00:07<02:48,  2.68it/s]
# Epoch 1 in training:   4%|▍         | 19/469 [00:07<02:49,  2.65it/s]
# Epoch 1 in training:   4%|▍         | 20/469 [00:07<02:48,  2.66it/s]
# Epoch 1 in training:   4%|▍         | 21/469 [00:08<02:42,  2.76it/s]
# Epoch 1 in training:   5%|▍         | 22/469 [00:08<02:34,  2.89it/s]
# Epoch 1 in training:   5%|▍         | 23/469 [00:08<02:30,  2.95it/s]
# Epoch 1 in training:   5%|▌         | 24/469 [00:09<02:27,  3.01it/s]
# Epoch 1 in training:   5%|▌         | 25/469 [00:09<02:27,  3.00it/s]
# Epoch 1 in training:   6%|▌         | 26/469 [00:09<02:27,  3.00it/s]
# Epoch 1 in training:   6%|▌         | 27/469 [00:10<02:25,  3.05it/s]
# Epoch 1 in training:   6%|▌         | 28/469 [00:10<02:23,  3.07it/s]
# Epoch 1 in training:   6%|▌         | 29/469 [00:10<02:22,  3.10it/s]
# Epoch 1 in training:   6%|▋         | 30/469 [00:11<02:23,  3.07it/s]
# Epoch 1 in training:   7%|▋         | 31/469 [00:11<02:21,  3.10it/s]
# Epoch 1 in training:   7%|▋         | 32/469 [00:11<02:19,  3.13it/s]
# Epoch 1 in training:   7%|▋         | 33/469 [00:12<02:20,  3.10it/s]
# Epoch 1 in training:   7%|▋         | 34/469 [00:12<02:21,  3.07it/s]
# Epoch 1 in training:   7%|▋         | 35/469 [00:12<02:19,  3.12it/s]
# Epoch 1 in training:   8%|▊         | 36/469 [00:13<02:19,  3.10it/s]
# Epoch 1 in training:   8%|▊         | 37/469 [00:13<02:27,  2.93it/s]
# Epoch 1 in training:   8%|▊         | 38/469 [00:13<02:41,  2.66it/s]
# Epoch 1 in training:   8%|▊         | 39/469 [00:14<02:50,  2.52it/s]
# Epoch 1 in training:   9%|▊         | 40/469 [00:14<02:52,  2.48it/s]
# Epoch 1 in training:   9%|▊         | 41/469 [00:15<02:59,  2.38it/s]
# Epoch 1 in training:   9%|▉         | 42/469 [00:15<03:07,  2.28it/s]
# Epoch 1 in training:   9%|▉         | 43/469 [00:16<02:59,  2.38it/s]
# Epoch 1 in training:   9%|▉         | 44/469 [00:16<02:47,  2.53it/s]
# Epoch 1 in training:  10%|▉         | 45/469 [00:16<02:42,  2.61it/s]
# Epoch 1 in training:  10%|▉         | 46/469 [00:17<02:42,  2.60it/s]
# Epoch 1 in training:  10%|█         | 47/469 [00:17<03:08,  2.24it/s]
# Epoch 1 in training:  10%|█         | 48/469 [00:18<03:08,  2.23it/s]
# Epoch 1 in training:  10%|█         | 49/469 [00:18<02:51,  2.44it/s]
# Epoch 1 in training:  11%|█         | 50/469 [00:18<02:39,  2.63it/s]
# Epoch 1 in training:  11%|█         | 51/469 [00:19<02:30,  2.78it/s]
# Epoch 1 in training:  11%|█         | 52/469 [00:19<02:25,  2.86it/s]
# Epoch 1 in training:  11%|█▏        | 53/469 [00:19<02:21,  2.94it/s]
# Epoch 1 in training:  12%|█▏        | 54/469 [00:20<02:16,  3.03it/s]
# Epoch 1 in training:  12%|█▏        | 55/469 [00:20<02:15,  3.05it/s]
# Epoch 1 in training:  12%|█▏        | 56/469 [00:20<02:12,  3.11it/s]
# Epoch 1 in training:  12%|█▏        | 57/469 [00:21<02:11,  3.14it/s]
# Epoch 1 in training:  12%|█▏        | 58/469 [00:21<02:11,  3.12it/s]
# Epoch 1 in training:  13%|█▎        | 59/469 [00:21<02:09,  3.17it/s]
# Epoch 1 in training:  13%|█▎        | 60/469 [00:21<02:08,  3.19it/s]
# Epoch 1 in training:  13%|█▎        | 61/469 [00:22<02:07,  3.20it/s]
# Epoch 1 in training:  13%|█▎        | 62/469 [00:22<02:13,  3.05it/s]
# Epoch 1 in training:  13%|█▎        | 63/469 [00:22<02:10,  3.11it/s]
# Epoch 1 in training:  14%|█▎        | 64/469 [00:23<02:09,  3.13it/s]
# Epoch 1 in training:  14%|█▍        | 65/469 [00:23<02:09,  3.12it/s]
# Epoch 1 in training:  14%|█▍        | 66/469 [00:23<02:08,  3.14it/s]
# Epoch 1 in training:  14%|█▍        | 67/469 [00:24<02:07,  3.14it/s]
# Epoch 1 in training:  14%|█▍        | 68/469 [00:24<02:07,  3.13it/s]
# Epoch 1 in training:  15%|█▍        | 69/469 [00:24<02:06,  3.15it/s]
# Epoch 1 in training:  15%|█▍        | 70/469 [00:25<02:06,  3.16it/s]
# Epoch 1 in training:  15%|█▌        | 71/469 [00:25<02:07,  3.11it/s]
# Epoch 1 in training:  15%|█▌        | 72/469 [00:25<02:05,  3.15it/s]
# Epoch 1 in training:  16%|█▌        | 73/469 [00:26<02:24,  2.74it/s]
# Epoch 1 in training:  16%|█▌        | 74/469 [00:26<02:34,  2.56it/s]
# Epoch 1 in training:  16%|█▌        | 75/469 [00:27<02:38,  2.48it/s]
# Epoch 1 in training:  16%|█▌        | 76/469 [00:27<02:40,  2.44it/s]
# Epoch 1 in training:  16%|█▋        | 77/469 [00:28<02:50,  2.30it/s]
# Epoch 1 in training:  17%|█▋        | 78/469 [00:28<03:03,  2.13it/s]
# Epoch 1 in training:  17%|█▋        | 79/469 [00:29<03:16,  1.99it/s]
# Epoch 1 in training:  17%|█▋        | 80/469 [00:29<03:14,  2.00it/s]
# Epoch 1 in training:  17%|█▋        | 81/469 [00:30<02:52,  2.25it/s]
# Epoch 1 in training:  17%|█▋        | 82/469 [00:30<02:39,  2.43it/s]
# Epoch 1 in training:  18%|█▊        | 83/469 [00:30<02:30,  2.56it/s]
# Epoch 1 in training:  18%|█▊        | 84/469 [00:31<02:21,  2.72it/s]
# Epoch 1 in training:  18%|█▊        | 85/469 [00:31<02:14,  2.85it/s]
# Epoch 1 in training:  18%|█▊        | 86/469 [00:31<02:09,  2.95it/s]
# Epoch 1 in training:  19%|█▊        | 87/469 [00:31<02:08,  2.98it/s]
# Epoch 1 in training:  19%|█▉        | 88/469 [00:32<02:05,  3.03it/s]
# Epoch 1 in training:  19%|█▉        | 89/469 [00:32<02:03,  3.08it/s]
# Epoch 1 in training:  19%|█▉        | 90/469 [00:32<02:01,  3.11it/s]
# Epoch 1 in training:  19%|█▉        | 91/469 [00:33<02:01,  3.10it/s]
# Epoch 1 in training:  20%|█▉        | 92/469 [00:33<02:07,  2.95it/s]
# Epoch 1 in training:  20%|█▉        | 93/469 [00:33<02:05,  3.00it/s]
# Epoch 1 in training:  20%|██        | 94/469 [00:34<02:02,  3.05it/s]
# Epoch 1 in training:  20%|██        | 95/469 [00:34<02:00,  3.09it/s]
# Epoch 1 in training:  20%|██        | 96/469 [00:34<02:00,  3.09it/s]
# Epoch 1 in training:  21%|██        | 97/469 [00:35<01:58,  3.13it/s]
# Epoch 1 in training:  21%|██        | 98/469 [00:35<01:58,  3.14it/s]
# Epoch 1 in training:  21%|██        | 99/469 [00:35<01:58,  3.12it/s]
# Epoch 1 in training:  21%|██▏       | 100/469 [00:36<01:56,  3.16it/s]
# Epoch 1 in training:  22%|██▏       | 101/469 [00:36<01:56,  3.17it/s]
# Epoch 1 in training:  22%|██▏       | 102/469 [00:36<01:59,  3.07it/s]
# Epoch 1 in training:  22%|██▏       | 103/469 [00:37<01:59,  3.07it/s]
# Epoch 1 in training:  22%|██▏       | 104/469 [00:37<01:57,  3.12it/s]
# Epoch 1 in training:  22%|██▏       | 105/469 [00:37<01:54,  3.17it/s]
# Epoch 1 in training:  23%|██▎       | 106/469 [00:38<01:55,  3.13it/s]
# Epoch 1 in training:  23%|██▎       | 107/469 [00:38<01:54,  3.15it/s]
# Epoch 1 in training:  23%|██▎       | 108/469 [00:38<01:54,  3.16it/s]
# Epoch 1 in training:  23%|██▎       | 109/469 [00:39<02:13,  2.70it/s]
# Epoch 1 in training:  23%|██▎       | 110/469 [00:39<02:26,  2.46it/s]
# Epoch 1 in training:  24%|██▎       | 111/469 [00:40<02:34,  2.31it/s]
# Epoch 1 in training:  24%|██▍       | 112/469 [00:40<02:44,  2.17it/s]
# Epoch 1 in training:  24%|██▍       | 113/469 [00:41<03:01,  1.96it/s]
# Epoch 1 in training:  24%|██▍       | 114/469 [00:41<03:18,  1.79it/s]
# Epoch 1 in training:  25%|██▍       | 115/469 [00:42<03:04,  1.92it/s]
# Epoch 1 in training:  25%|██▍       | 116/469 [00:42<02:42,  2.17it/s]
# Epoch 1 in training:  25%|██▍       | 117/469 [00:43<02:26,  2.41it/s]
# Epoch 1 in training:  25%|██▌       | 118/469 [00:43<02:16,  2.56it/s]
# Epoch 1 in training:  25%|██▌       | 119/469 [00:43<02:09,  2.71it/s]
# Epoch 1 in training:  26%|██▌       | 120/469 [00:44<02:02,  2.84it/s]
# Epoch 1 in training:  26%|██▌       | 121/469 [00:44<02:00,  2.89it/s]
# Epoch 1 in training:  26%|██▌       | 122/469 [00:44<01:56,  2.97it/s]
# Epoch 1 in training:  26%|██▌       | 123/469 [00:44<01:54,  3.03it/s]
# Epoch 1 in training:  26%|██▋       | 124/469 [00:45<01:53,  3.03it/s]
# Epoch 1 in training:  27%|██▋       | 125/469 [00:45<01:51,  3.07it/s]
# Epoch 1 in training:  27%|██▋       | 126/469 [00:45<01:50,  3.10it/s]
# Epoch 1 in training:  27%|██▋       | 127/469 [00:46<01:51,  3.07it/s]
# Epoch 1 in training:  27%|██▋       | 128/469 [00:46<02:15,  2.52it/s]
# Epoch 1 in training:  28%|██▊       | 129/469 [00:47<02:06,  2.70it/s]
# Epoch 1 in training:  28%|██▊       | 130/469 [00:47<02:00,  2.81it/s]
# Epoch 1 in training:  28%|██▊       | 131/469 [00:47<01:56,  2.91it/s]
# Epoch 1 in training:  28%|██▊       | 132/469 [00:48<01:52,  3.00it/s]
# Epoch 1 in training:  28%|██▊       | 133/469 [00:48<01:54,  2.94it/s]
# Epoch 1 in training:  29%|██▊       | 134/469 [00:48<01:50,  3.02it/s]
# Epoch 1 in training:  29%|██▉       | 135/469 [00:49<01:49,  3.06it/s]
# Epoch 1 in training:  29%|██▉       | 136/469 [00:49<01:52,  2.96it/s]
# Epoch 1 in training:  29%|██▉       | 137/469 [00:49<01:49,  3.03it/s]
# Epoch 1 in training:  29%|██▉       | 138/469 [00:50<01:47,  3.09it/s]
# Epoch 1 in training:  30%|██▉       | 139/469 [00:50<01:46,  3.10it/s]
# Epoch 1 in training:  30%|██▉       | 140/469 [00:50<01:45,  3.10it/s]
# Epoch 1 in training:  30%|███       | 141/469 [00:51<01:44,  3.13it/s]
# Epoch 1 in training:  30%|███       | 142/469 [00:51<01:43,  3.15it/s]
# Epoch 1 in training:  30%|███       | 143/469 [00:51<01:43,  3.14it/s]
# Epoch 1 in training:  31%|███       | 144/469 [00:51<01:46,  3.04it/s]
# Epoch 1 in training:  31%|███       | 145/469 [00:52<01:54,  2.83it/s]
# Epoch 1 in training:  31%|███       | 146/469 [00:53<02:21,  2.28it/s]
# Epoch 1 in training:  31%|███▏      | 147/469 [00:53<02:36,  2.06it/s]
# Epoch 1 in training:  32%|███▏      | 148/469 [00:54<02:34,  2.08it/s]
# Epoch 1 in training:  32%|███▏      | 149/469 [00:54<02:28,  2.16it/s]
# Epoch 1 in training:  32%|███▏      | 150/469 [00:55<02:28,  2.15it/s]
# Epoch 1 in training:  32%|███▏      | 151/469 [00:55<02:32,  2.09it/s]
# Epoch 1 in training:  32%|███▏      | 152/469 [00:55<02:23,  2.21it/s]
# Epoch 1 in training:  33%|███▎      | 153/469 [00:56<02:12,  2.39it/s]
# Epoch 1 in training:  33%|███▎      | 154/469 [00:56<02:03,  2.55it/s]
# Epoch 1 in training:  33%|███▎      | 155/469 [00:56<01:56,  2.69it/s]
# Epoch 1 in training:  33%|███▎      | 156/469 [00:57<01:54,  2.74it/s]
# Epoch 1 in training:  33%|███▎      | 157/469 [00:57<01:48,  2.86it/s]
# Epoch 1 in training:  34%|███▎      | 158/469 [00:57<01:46,  2.93it/s]
# Epoch 1 in training:  34%|███▍      | 159/469 [00:58<01:43,  2.99it/s]
# Epoch 1 in training:  34%|███▍      | 160/469 [00:58<01:41,  3.05it/s]
# Epoch 1 in training:  34%|███▍      | 161/469 [00:58<01:41,  3.03it/s]
# Epoch 1 in training:  35%|███▍      | 162/469 [00:59<01:40,  3.06it/s]
# Epoch 1 in training:  35%|███▍      | 163/469 [00:59<01:38,  3.11it/s]
# Epoch 1 in training:  35%|███▍      | 164/469 [00:59<01:37,  3.13it/s]
# Epoch 1 in training:  35%|███▌      | 165/469 [01:00<01:37,  3.11it/s]
# Epoch 1 in training:  35%|███▌      | 166/469 [01:00<01:38,  3.09it/s]
# Epoch 1 in training:  36%|███▌      | 167/469 [01:00<01:37,  3.11it/s]
# Epoch 1 in training:  36%|███▌      | 168/469 [01:01<01:37,  3.09it/s]
# Epoch 1 in training:  36%|███▌      | 169/469 [01:01<01:36,  3.11it/s]
# Epoch 1 in training:  36%|███▌      | 170/469 [01:01<01:39,  3.02it/s]
# Epoch 1 in training:  36%|███▋      | 171/469 [01:02<01:38,  3.03it/s]
# Epoch 1 in training:  37%|███▋      | 172/469 [01:02<01:38,  3.03it/s]
# Epoch 1 in training:  37%|███▋      | 173/469 [01:02<01:38,  3.02it/s]
# Epoch 1 in training:  37%|███▋      | 174/469 [01:03<01:38,  2.99it/s]
# Epoch 1 in training:  37%|███▋      | 175/469 [01:03<01:37,  3.00it/s]
# Epoch 1 in training:  38%|███▊      | 176/469 [01:03<01:36,  3.04it/s]
# Epoch 1 in training:  38%|███▊      | 177/469 [01:04<01:40,  2.89it/s]
# Epoch 1 in training:  38%|███▊      | 178/469 [01:04<01:49,  2.65it/s]
# Epoch 1 in training:  38%|███▊      | 179/469 [01:05<02:08,  2.26it/s]
# Epoch 1 in training:  38%|███▊      | 180/469 [01:05<02:01,  2.38it/s]
# Epoch 1 in training:  39%|███▊      | 181/469 [01:05<02:02,  2.36it/s]
# Epoch 1 in training:  39%|███▉      | 182/469 [01:06<02:04,  2.30it/s]
# Epoch 1 in training:  39%|███▉      | 183/469 [01:06<02:03,  2.32it/s]
# Epoch 1 in training:  39%|███▉      | 184/469 [01:07<02:03,  2.31it/s]
# Epoch 1 in training:  39%|███▉      | 185/469 [01:07<02:07,  2.23it/s]
# Epoch 1 in training:  40%|███▉      | 186/469 [01:08<02:12,  2.13it/s]
# Epoch 1 in training:  40%|███▉      | 187/469 [01:08<02:00,  2.35it/s]
# Epoch 1 in training:  40%|████      | 188/469 [01:08<01:49,  2.56it/s]
# Epoch 1 in training:  40%|████      | 189/469 [01:09<01:44,  2.68it/s]
# Epoch 1 in training:  41%|████      | 190/469 [01:09<01:39,  2.81it/s]
# Epoch 1 in training:  41%|████      | 191/469 [01:09<01:35,  2.91it/s]
# Epoch 1 in training:  41%|████      | 192/469 [01:10<01:35,  2.89it/s]
# Epoch 1 in training:  41%|████      | 193/469 [01:10<01:33,  2.94it/s]
# Epoch 1 in training:  41%|████▏     | 194/469 [01:10<01:31,  2.99it/s]
# Epoch 1 in training:  42%|████▏     | 195/469 [01:11<01:29,  3.05it/s]
# Epoch 1 in training:  42%|████▏     | 196/469 [01:11<01:29,  3.07it/s]
# Epoch 1 in training:  42%|████▏     | 197/469 [01:11<01:28,  3.08it/s]
# Epoch 1 in training:  42%|████▏     | 198/469 [01:12<01:27,  3.10it/s]
# Epoch 1 in training:  42%|████▏     | 199/469 [01:12<01:28,  3.05it/s]
# Epoch 1 in training:  43%|████▎     | 200/469 [01:12<01:29,  2.99it/s]
# Epoch 1 in training:  43%|████▎     | 201/469 [01:13<01:28,  3.02it/s]
# Epoch 1 in training:  43%|████▎     | 202/469 [01:13<01:29,  3.00it/s]
# Epoch 1 in training:  43%|████▎     | 203/469 [01:13<01:27,  3.04it/s]
# Epoch 1 in training:  43%|████▎     | 204/469 [01:14<01:25,  3.08it/s]
# Epoch 1 in training:  44%|████▎     | 205/469 [01:14<01:26,  3.03it/s]
# Epoch 1 in training:  44%|████▍     | 206/469 [01:14<01:25,  3.08it/s]
# Epoch 1 in training:  44%|████▍     | 207/469 [01:15<01:26,  3.03it/s]
# Epoch 1 in training:  44%|████▍     | 208/469 [01:15<01:28,  2.93it/s]
# Epoch 1 in training:  45%|████▍     | 209/469 [01:16<02:07,  2.05it/s]
# Epoch 1 in training:  45%|████▍     | 210/469 [01:17<02:30,  1.72it/s]
# Epoch 1 in training:  45%|████▍     | 211/469 [01:17<02:08,  2.00it/s]
# Epoch 1 in training:  45%|████▌     | 212/469 [01:18<02:17,  1.87it/s]
# Epoch 1 in training:  45%|████▌     | 213/469 [01:18<02:02,  2.08it/s]
# Epoch 1 in training:  46%|████▌     | 214/469 [01:18<02:05,  2.04it/s]
# Epoch 1 in training:  46%|████▌     | 215/469 [01:19<02:01,  2.09it/s]
# Epoch 1 in training:  46%|████▌     | 216/469 [01:19<01:58,  2.13it/s]
# Epoch 1 in training:  46%|████▋     | 217/469 [01:20<02:01,  2.07it/s]
# Epoch 1 in training:  46%|████▋     | 218/469 [01:20<02:03,  2.03it/s]
# Epoch 1 in training:  47%|████▋     | 219/469 [01:21<01:53,  2.20it/s]
# Epoch 1 in training:  47%|████▋     | 220/469 [01:21<01:42,  2.43it/s]
# Epoch 1 in training:  47%|████▋     | 221/469 [01:22<01:49,  2.27it/s]
# Epoch 1 in training:  47%|████▋     | 222/469 [01:22<01:39,  2.47it/s]
# Epoch 1 in training:  48%|████▊     | 223/469 [01:22<01:33,  2.63it/s]
# Epoch 1 in training:  48%|████▊     | 224/469 [01:23<01:30,  2.70it/s]
# Epoch 1 in training:  48%|████▊     | 225/469 [01:23<01:27,  2.80it/s]
# Epoch 1 in training:  48%|████▊     | 226/469 [01:23<01:24,  2.89it/s]
# Epoch 1 in training:  48%|████▊     | 227/469 [01:24<01:23,  2.91it/s]
# Epoch 1 in training:  49%|████▊     | 228/469 [01:24<01:21,  2.96it/s]
# Epoch 1 in training:  49%|████▉     | 229/469 [01:24<01:21,  2.95it/s]
# Epoch 1 in training:  49%|████▉     | 230/469 [01:25<01:20,  2.97it/s]
# Epoch 1 in training:  49%|████▉     | 231/469 [01:25<01:19,  3.01it/s]
# Epoch 1 in training:  49%|████▉     | 232/469 [01:25<01:17,  3.05it/s]
# Epoch 1 in training:  50%|████▉     | 233/469 [01:26<01:18,  3.02it/s]
# Epoch 1 in training:  50%|████▉     | 234/469 [01:26<01:19,  2.97it/s]
# Epoch 1 in training:  50%|█████     | 235/469 [01:26<01:17,  3.02it/s]
# Epoch 1 in training:  50%|█████     | 236/469 [01:27<01:17,  3.00it/s]
# Epoch 1 in training:  51%|█████     | 237/469 [01:27<01:20,  2.89it/s]
# Epoch 1 in training:  51%|█████     | 238/469 [01:27<01:28,  2.60it/s]
# Epoch 1 in training:  51%|█████     | 239/469 [01:28<01:40,  2.29it/s]
# Epoch 1 in training:  51%|█████     | 240/469 [01:28<01:36,  2.38it/s]
# Epoch 1 in training:  51%|█████▏    | 241/469 [01:29<01:30,  2.53it/s]
# Epoch 1 in training:  52%|█████▏    | 242/469 [01:29<01:24,  2.68it/s]
# Epoch 1 in training:  52%|█████▏    | 243/469 [01:29<01:20,  2.79it/s]
# Epoch 1 in training:  52%|█████▏    | 244/469 [01:30<01:18,  2.85it/s]
# Epoch 1 in training:  52%|█████▏    | 245/469 [01:30<01:16,  2.91it/s]
# Epoch 1 in training:  52%|█████▏    | 246/469 [01:30<01:14,  2.98it/s]
# Epoch 1 in training:  53%|█████▎    | 247/469 [01:31<01:20,  2.74it/s]
# Epoch 1 in training:  53%|█████▎    | 248/469 [01:31<01:26,  2.56it/s]
# Epoch 1 in training:  53%|█████▎    | 249/469 [01:32<01:29,  2.46it/s]
# Epoch 1 in training:  53%|█████▎    | 250/469 [01:32<01:32,  2.37it/s]
# Epoch 1 in training:  54%|█████▎    | 251/469 [01:33<01:36,  2.26it/s]
# Epoch 1 in training:  54%|█████▎    | 252/469 [01:33<01:41,  2.15it/s]
# Epoch 1 in training:  54%|█████▍    | 253/469 [01:33<01:32,  2.32it/s]
# Epoch 1 in training:  54%|█████▍    | 254/469 [01:34<01:25,  2.51it/s]
# Epoch 1 in training:  54%|█████▍    | 255/469 [01:34<01:21,  2.64it/s]
# Epoch 1 in training:  55%|█████▍    | 256/469 [01:34<01:17,  2.76it/s]
# Epoch 1 in training:  55%|█████▍    | 257/469 [01:35<01:14,  2.85it/s]
# Epoch 1 in training:  55%|█████▌    | 258/469 [01:35<01:12,  2.89it/s]
# Epoch 1 in training:  55%|█████▌    | 259/469 [01:35<01:11,  2.94it/s]
# Epoch 1 in training:  55%|█████▌    | 260/469 [01:36<01:10,  2.98it/s]
# Epoch 1 in training:  56%|█████▌    | 261/469 [01:36<01:10,  2.97it/s]
# Epoch 1 in training:  56%|█████▌    | 262/469 [01:36<01:09,  3.00it/s]
# Epoch 1 in training:  56%|█████▌    | 263/469 [01:37<01:09,  2.98it/s]
# Epoch 1 in training:  56%|█████▋    | 264/469 [01:37<01:08,  2.98it/s]
# Epoch 1 in training:  57%|█████▋    | 265/469 [01:37<01:07,  3.04it/s]
# Epoch 1 in training:  57%|█████▋    | 266/469 [01:38<01:06,  3.04it/s]
# Epoch 1 in training:  57%|█████▋    | 267/469 [01:38<01:06,  3.03it/s]
# Epoch 1 in training:  57%|█████▋    | 268/469 [01:38<01:09,  2.91it/s]
# Epoch 1 in training:  57%|█████▋    | 269/469 [01:39<01:20,  2.49it/s]
# Epoch 1 in training:  58%|█████▊    | 270/469 [01:39<01:28,  2.24it/s]
# Epoch 1 in training:  58%|█████▊    | 271/469 [01:40<01:20,  2.45it/s]
# Epoch 1 in training:  58%|█████▊    | 272/469 [01:40<01:16,  2.58it/s]
# Epoch 1 in training:  58%|█████▊    | 273/469 [01:40<01:11,  2.73it/s]
# Epoch 1 in training:  58%|█████▊    | 274/469 [01:41<01:08,  2.84it/s]
# Epoch 1 in training:  59%|█████▊    | 275/469 [01:41<01:07,  2.88it/s]
# Epoch 1 in training:  59%|█████▉    | 276/469 [01:41<01:05,  2.94it/s]
# Epoch 1 in training:  59%|█████▉    | 277/469 [01:42<01:03,  3.00it/s]
# Epoch 1 in training:  59%|█████▉    | 278/469 [01:42<01:02,  3.05it/s]
# Epoch 1 in training:  59%|█████▉    | 279/469 [01:42<01:02,  3.03it/s]
# Epoch 1 in training:  60%|█████▉    | 280/469 [01:43<01:01,  3.05it/s]
# Epoch 1 in training:  60%|█████▉    | 281/469 [01:43<01:01,  3.08it/s]
# Epoch 1 in training:  60%|██████    | 282/469 [01:44<01:08,  2.74it/s]
# Epoch 1 in training:  60%|██████    | 283/469 [01:44<01:11,  2.58it/s]
# Epoch 1 in training:  61%|██████    | 284/469 [01:44<01:14,  2.48it/s]
# Epoch 1 in training:  61%|██████    | 285/469 [01:45<01:15,  2.44it/s]
# Epoch 1 in training:  61%|██████    | 286/469 [01:45<01:19,  2.30it/s]
# Epoch 1 in training:  61%|██████    | 287/469 [01:46<01:22,  2.20it/s]
# Epoch 1 in training:  61%|██████▏   | 288/469 [01:46<01:15,  2.39it/s]
# Epoch 1 in training:  62%|██████▏   | 289/469 [01:46<01:10,  2.56it/s]
# Epoch 1 in training:  62%|██████▏   | 290/469 [01:47<01:06,  2.71it/s]
# Epoch 1 in training:  62%|██████▏   | 291/469 [01:47<01:03,  2.82it/s]
# Epoch 1 in training:  62%|██████▏   | 292/469 [01:47<01:01,  2.89it/s]
# Epoch 1 in training:  62%|██████▏   | 293/469 [01:48<00:59,  2.96it/s]
# Epoch 1 in training:  63%|██████▎   | 294/469 [01:48<00:57,  3.02it/s]
# Epoch 1 in training:  63%|██████▎   | 295/469 [01:48<00:58,  3.00it/s]
# Epoch 1 in training:  63%|██████▎   | 296/469 [01:49<00:57,  3.02it/s]
# Epoch 1 in training:  63%|██████▎   | 297/469 [01:49<00:57,  3.02it/s]
# Epoch 1 in training:  64%|██████▎   | 298/469 [01:49<00:55,  3.07it/s]
# Epoch 1 in training:  64%|██████▍   | 299/469 [01:50<00:58,  2.90it/s]
# Epoch 1 in training:  64%|██████▍   | 300/469 [01:50<00:59,  2.83it/s]
# Epoch 1 in training:  64%|██████▍   | 301/469 [01:51<01:09,  2.42it/s]
# Epoch 1 in training:  64%|██████▍   | 302/469 [01:51<01:12,  2.31it/s]
# Epoch 1 in training:  65%|██████▍   | 303/469 [01:51<01:06,  2.48it/s]
# Epoch 1 in training:  65%|██████▍   | 304/469 [01:52<01:02,  2.65it/s]
# Epoch 1 in training:  65%|██████▌   | 305/469 [01:52<00:58,  2.79it/s]
# Epoch 1 in training:  65%|██████▌   | 306/469 [01:52<00:56,  2.88it/s]
# Epoch 1 in training:  65%|██████▌   | 307/469 [01:53<00:55,  2.90it/s]
# Epoch 1 in training:  66%|██████▌   | 308/469 [01:53<00:53,  2.98it/s]
# Epoch 1 in training:  66%|██████▌   | 309/469 [01:53<00:52,  3.03it/s]
# Epoch 1 in training:  66%|██████▌   | 310/469 [01:54<00:52,  3.00it/s]
# Epoch 1 in training:  66%|██████▋   | 311/469 [01:54<00:51,  3.05it/s]
# Epoch 1 in training:  67%|██████▋   | 312/469 [01:54<00:51,  3.04it/s]
# Epoch 1 in training:  67%|██████▋   | 313/469 [01:55<00:51,  3.02it/s]
# Epoch 1 in training:  67%|██████▋   | 314/469 [01:55<00:52,  2.96it/s]
# Epoch 1 in training:  67%|██████▋   | 315/469 [01:55<00:53,  2.87it/s]
# Epoch 1 in training:  67%|██████▋   | 316/469 [01:56<00:55,  2.75it/s]
# Epoch 1 in training:  68%|██████▊   | 317/469 [01:56<00:59,  2.55it/s]
# Epoch 1 in training:  68%|██████▊   | 318/469 [01:57<01:01,  2.44it/s]
# Epoch 1 in training:  68%|██████▊   | 319/469 [01:57<01:01,  2.43it/s]
# Epoch 1 in training:  68%|██████▊   | 320/469 [01:58<01:02,  2.37it/s]
# Epoch 1 in training:  68%|██████▊   | 321/469 [01:58<01:05,  2.26it/s]
# Epoch 1 in training:  69%|██████▊   | 322/469 [01:59<01:03,  2.31it/s]
# Epoch 1 in training:  69%|██████▉   | 323/469 [01:59<00:58,  2.48it/s]
# Epoch 1 in training:  69%|██████▉   | 324/469 [01:59<00:54,  2.67it/s]
# Epoch 1 in training:  69%|██████▉   | 325/469 [02:00<00:51,  2.79it/s]
# Epoch 1 in training:  70%|██████▉   | 326/469 [02:00<00:50,  2.84it/s]
# Epoch 1 in training:  70%|██████▉   | 327/469 [02:00<00:48,  2.94it/s]
# Epoch 1 in training:  70%|██████▉   | 328/469 [02:00<00:46,  3.01it/s]
# Epoch 1 in training:  70%|███████   | 329/469 [02:01<00:45,  3.05it/s]
# Epoch 1 in training:  70%|███████   | 330/469 [02:01<00:46,  2.98it/s]
# Epoch 1 in training:  71%|███████   | 331/469 [02:01<00:47,  2.93it/s]
# Epoch 1 in training:  71%|███████   | 332/469 [02:02<00:56,  2.43it/s]
# Epoch 1 in training:  71%|███████   | 333/469 [02:03<00:59,  2.28it/s]
# Epoch 1 in training:  71%|███████   | 334/469 [02:03<00:54,  2.48it/s]
# Epoch 1 in training:  71%|███████▏  | 335/469 [02:03<00:51,  2.62it/s]
# Epoch 1 in training:  72%|███████▏  | 336/469 [02:04<00:48,  2.76it/s]
# Epoch 1 in training:  72%|███████▏  | 337/469 [02:04<00:46,  2.85it/s]
# Epoch 1 in training:  72%|███████▏  | 338/469 [02:04<00:47,  2.75it/s]
# Epoch 1 in training:  72%|███████▏  | 339/469 [02:05<00:45,  2.85it/s]
# Epoch 1 in training:  72%|███████▏  | 340/469 [02:05<00:44,  2.92it/s]
# Epoch 1 in training:  73%|███████▎  | 341/469 [02:05<00:43,  2.94it/s]
# Epoch 1 in training:  73%|███████▎  | 342/469 [02:06<00:42,  2.98it/s]
# Epoch 1 in training:  73%|███████▎  | 343/469 [02:06<00:42,  2.99it/s]
# Epoch 1 in training:  73%|███████▎  | 344/469 [02:06<00:41,  3.00it/s]
# Epoch 1 in training:  74%|███████▎  | 345/469 [02:07<00:40,  3.07it/s]
# Epoch 1 in training:  74%|███████▍  | 346/469 [02:07<00:40,  3.07it/s]
# Epoch 1 in training:  74%|███████▍  | 347/469 [02:07<00:39,  3.06it/s]
# Epoch 1 in training:  74%|███████▍  | 348/469 [02:08<00:38,  3.11it/s]
# Epoch 1 in training:  74%|███████▍  | 349/469 [02:08<00:38,  3.10it/s]
# Epoch 1 in training:  75%|███████▍  | 350/469 [02:08<00:38,  3.10it/s]
# Epoch 1 in training:  75%|███████▍  | 351/469 [02:09<00:39,  3.01it/s]
# Epoch 1 in training:  75%|███████▌  | 352/469 [02:09<00:43,  2.66it/s]
# Epoch 1 in training:  75%|███████▌  | 353/469 [02:09<00:46,  2.52it/s]
# Epoch 1 in training:  75%|███████▌  | 354/469 [02:10<00:48,  2.38it/s]
# Epoch 1 in training:  76%|███████▌  | 355/469 [02:10<00:49,  2.29it/s]
# Epoch 1 in training:  76%|███████▌  | 356/469 [02:11<00:51,  2.19it/s]
# Epoch 1 in training:  76%|███████▌  | 357/469 [02:11<00:49,  2.28it/s]
# Epoch 1 in training:  76%|███████▋  | 358/469 [02:12<00:45,  2.46it/s]
# Epoch 1 in training:  77%|███████▋  | 359/469 [02:12<00:42,  2.62it/s]
# Epoch 1 in training:  77%|███████▋  | 360/469 [02:12<00:39,  2.76it/s]
# Epoch 1 in training:  77%|███████▋  | 361/469 [02:13<00:38,  2.81it/s]
# Epoch 1 in training:  77%|███████▋  | 362/469 [02:13<00:38,  2.78it/s]
# Epoch 1 in training:  77%|███████▋  | 363/469 [02:13<00:43,  2.42it/s]
# Epoch 1 in training:  78%|███████▊  | 364/469 [02:14<00:47,  2.20it/s]
# Epoch 1 in training:  78%|███████▊  | 365/469 [02:14<00:43,  2.41it/s]
# Epoch 1 in training:  78%|███████▊  | 366/469 [02:15<00:40,  2.56it/s]
# Epoch 1 in training:  78%|███████▊  | 367/469 [02:15<00:37,  2.72it/s]
# Epoch 1 in training:  78%|███████▊  | 368/469 [02:15<00:35,  2.83it/s]
# Epoch 1 in training:  79%|███████▊  | 369/469 [02:16<00:35,  2.84it/s]
# Epoch 1 in training:  79%|███████▉  | 370/469 [02:16<00:33,  2.93it/s]
# Epoch 1 in training:  79%|███████▉  | 371/469 [02:16<00:32,  3.00it/s]
# Epoch 1 in training:  79%|███████▉  | 372/469 [02:17<00:32,  2.97it/s]
# Epoch 1 in training:  80%|███████▉  | 373/469 [02:17<00:32,  3.00it/s]
# Epoch 1 in training:  80%|███████▉  | 374/469 [02:17<00:31,  3.06it/s]
# Epoch 1 in training:  80%|███████▉  | 375/469 [02:18<00:30,  3.04it/s]
# Epoch 1 in training:  80%|████████  | 376/469 [02:18<00:35,  2.63it/s]
# Epoch 1 in training:  80%|████████  | 377/469 [02:18<00:33,  2.78it/s]
# Epoch 1 in training:  81%|████████  | 378/469 [02:19<00:32,  2.84it/s]
# Epoch 1 in training:  81%|████████  | 379/469 [02:19<00:30,  2.94it/s]
# Epoch 1 in training:  81%|████████  | 380/469 [02:19<00:29,  3.00it/s]
# Epoch 1 in training:  81%|████████  | 381/469 [02:20<00:29,  3.00it/s]
# Epoch 1 in training:  81%|████████▏ | 382/469 [02:20<00:28,  3.05it/s]
# Epoch 1 in training:  82%|████████▏ | 383/469 [02:20<00:27,  3.09it/s]
# Epoch 1 in training:  82%|████████▏ | 384/469 [02:21<00:27,  3.04it/s]
# Epoch 1 in training:  82%|████████▏ | 385/469 [02:21<00:28,  2.98it/s]
# Epoch 1 in training:  82%|████████▏ | 386/469 [02:22<00:31,  2.62it/s]
# Epoch 1 in training:  83%|████████▎ | 387/469 [02:22<00:33,  2.46it/s]
# Epoch 1 in training:  83%|████████▎ | 388/469 [02:22<00:33,  2.39it/s]
# Epoch 1 in training:  83%|████████▎ | 389/469 [02:23<00:35,  2.26it/s]
# Epoch 1 in training:  83%|████████▎ | 390/469 [02:23<00:36,  2.19it/s]
# Epoch 1 in training:  83%|████████▎ | 391/469 [02:24<00:34,  2.25it/s]
# Epoch 1 in training:  84%|████████▎ | 392/469 [02:24<00:32,  2.40it/s]
# Epoch 1 in training:  84%|████████▍ | 393/469 [02:25<00:31,  2.40it/s]
# Epoch 1 in training:  84%|████████▍ | 394/469 [02:25<00:34,  2.17it/s]
# Epoch 1 in training:  84%|████████▍ | 395/469 [02:26<00:33,  2.21it/s]
# Epoch 1 in training:  84%|████████▍ | 396/469 [02:26<00:31,  2.35it/s]
# Epoch 1 in training:  85%|████████▍ | 397/469 [02:26<00:28,  2.54it/s]
# Epoch 1 in training:  85%|████████▍ | 398/469 [02:27<00:26,  2.69it/s]
# Epoch 1 in training:  85%|████████▌ | 399/469 [02:27<00:25,  2.77it/s]
# Epoch 1 in training:  85%|████████▌ | 400/469 [02:27<00:23,  2.88it/s]
# Epoch 1 in training:  86%|████████▌ | 401/469 [02:28<00:23,  2.95it/s]
# Epoch 1 in training:  86%|████████▌ | 402/469 [02:28<00:22,  2.95it/s]
# Epoch 1 in training:  86%|████████▌ | 403/469 [02:28<00:21,  3.02it/s]
# Epoch 1 in training:  86%|████████▌ | 404/469 [02:29<00:21,  3.07it/s]
# Epoch 1 in training:  86%|████████▋ | 405/469 [02:29<00:20,  3.08it/s]
# Epoch 1 in training:  87%|████████▋ | 406/469 [02:29<00:20,  3.08it/s]
# Epoch 1 in training:  87%|████████▋ | 407/469 [02:30<00:19,  3.10it/s]
# Epoch 1 in training:  87%|████████▋ | 408/469 [02:30<00:19,  3.09it/s]
# Epoch 1 in training:  87%|████████▋ | 409/469 [02:30<00:19,  3.09it/s]
# Epoch 1 in training:  87%|████████▋ | 410/469 [02:31<00:19,  3.09it/s]
# Epoch 1 in training:  88%|████████▊ | 411/469 [02:31<00:18,  3.09it/s]
# Epoch 1 in training:  88%|████████▊ | 412/469 [02:31<00:18,  3.09it/s]
# Epoch 1 in training:  88%|████████▊ | 413/469 [02:31<00:17,  3.14it/s]
# Epoch 1 in training:  88%|████████▊ | 414/469 [02:32<00:17,  3.08it/s]
# Epoch 1 in training:  88%|████████▊ | 415/469 [02:32<00:17,  3.08it/s]
# Epoch 1 in training:  89%|████████▊ | 416/469 [02:32<00:16,  3.14it/s]
# Epoch 1 in training:  89%|████████▉ | 417/469 [02:33<00:16,  3.10it/s]
# Epoch 1 in training:  89%|████████▉ | 418/469 [02:33<00:16,  3.11it/s]
# Epoch 1 in training:  89%|████████▉ | 419/469 [02:33<00:16,  3.11it/s]
# Epoch 1 in training:  90%|████████▉ | 420/469 [02:34<00:16,  2.97it/s]
# Epoch 1 in training:  90%|████████▉ | 421/469 [02:34<00:18,  2.64it/s]
# Epoch 1 in training:  90%|████████▉ | 422/469 [02:35<00:18,  2.53it/s]
# Epoch 1 in training:  90%|█████████ | 423/469 [02:35<00:18,  2.45it/s]
# Epoch 1 in training:  90%|█████████ | 424/469 [02:36<00:19,  2.34it/s]
# Epoch 1 in training:  91%|█████████ | 425/469 [02:36<00:20,  2.13it/s]
# Epoch 1 in training:  91%|█████████ | 426/469 [02:37<00:22,  1.93it/s]
# Epoch 1 in training:  91%|█████████ | 427/469 [02:37<00:22,  1.88it/s]
# Epoch 1 in training:  91%|█████████▏| 428/469 [02:38<00:19,  2.14it/s]
# Epoch 1 in training:  91%|█████████▏| 429/469 [02:38<00:16,  2.36it/s]
# Epoch 1 in training:  92%|█████████▏| 430/469 [02:38<00:15,  2.55it/s]
# Epoch 1 in training:  92%|█████████▏| 431/469 [02:39<00:14,  2.67it/s]
# Epoch 1 in training:  92%|█████████▏| 432/469 [02:39<00:13,  2.79it/s]
# Epoch 1 in training:  92%|█████████▏| 433/469 [02:39<00:12,  2.91it/s]
# Epoch 1 in training:  93%|█████████▎| 434/469 [02:40<00:11,  2.93it/s]
# Epoch 1 in training:  93%|█████████▎| 435/469 [02:40<00:11,  2.99it/s]
# Epoch 1 in training:  93%|█████████▎| 436/469 [02:40<00:10,  3.05it/s]
# Epoch 1 in training:  93%|█████████▎| 437/469 [02:41<00:10,  3.05it/s]
# Epoch 1 in training:  93%|█████████▎| 438/469 [02:41<00:10,  3.07it/s]
# Epoch 1 in training:  94%|█████████▎| 439/469 [02:41<00:09,  3.11it/s]
# Epoch 1 in training:  94%|█████████▍| 440/469 [02:42<00:09,  3.09it/s]
# Epoch 1 in training:  94%|█████████▍| 441/469 [02:42<00:09,  3.10it/s]
# Epoch 1 in training:  94%|█████████▍| 442/469 [02:42<00:08,  3.10it/s]
# Epoch 1 in training:  94%|█████████▍| 443/469 [02:43<00:08,  3.07it/s]
# Epoch 1 in training:  95%|█████████▍| 444/469 [02:43<00:08,  2.98it/s]
# Epoch 1 in training:  95%|█████████▍| 445/469 [02:43<00:07,  3.04it/s]
# Epoch 1 in training:  95%|█████████▌| 446/469 [02:43<00:07,  3.08it/s]
# Epoch 1 in training:  95%|█████████▌| 447/469 [02:44<00:07,  3.07it/s]
# Epoch 1 in training:  96%|█████████▌| 448/469 [02:44<00:06,  3.09it/s]
# Epoch 1 in training:  96%|█████████▌| 449/469 [02:44<00:06,  3.13it/s]
# Epoch 1 in training:  96%|█████████▌| 450/469 [02:45<00:06,  3.09it/s]
# Epoch 1 in training:  96%|█████████▌| 451/469 [02:45<00:05,  3.09it/s]
# Epoch 1 in training:  96%|█████████▋| 452/469 [02:45<00:05,  3.13it/s]
# Epoch 1 in training:  97%|█████████▋| 453/469 [02:46<00:05,  3.06it/s]
# Epoch 1 in training:  97%|█████████▋| 454/469 [02:46<00:04,  3.07it/s]
# Epoch 1 in training:  97%|█████████▋| 455/469 [02:46<00:04,  3.08it/s]
# Epoch 1 in training:  97%|█████████▋| 456/469 [02:47<00:04,  2.84it/s]
# Epoch 1 in training:  97%|█████████▋| 457/469 [02:47<00:04,  2.62it/s]
# Epoch 1 in training:  98%|█████████▊| 458/469 [02:48<00:04,  2.44it/s]
# Epoch 1 in training:  98%|█████████▊| 459/469 [02:48<00:04,  2.31it/s]
# Epoch 1 in training:  98%|█████████▊| 460/469 [02:49<00:04,  2.03it/s]
# Epoch 1 in training:  98%|█████████▊| 461/469 [02:50<00:04,  1.82it/s]
# Epoch 1 in training:  99%|█████████▊| 462/469 [02:50<00:03,  1.83it/s]
# Epoch 1 in training:  99%|█████████▊| 463/469 [02:50<00:02,  2.10it/s]
# Epoch 1 in training:  99%|█████████▉| 464/469 [02:51<00:02,  2.33it/s]
# Epoch 1 in training:  99%|█████████▉| 465/469 [02:51<00:01,  2.49it/s]
# Epoch 1 in training:  99%|█████████▉| 466/469 [02:51<00:01,  2.68it/s]
# Epoch 1 in training: 100%|█████████▉| 467/469 [02:52<00:00,  2.81it/s]
# Epoch 1 in training: 100%|█████████▉| 468/469 [02:52<00:00,  2.86it/s]
# Epoch 1 in training: 100%|██████████| 469/469 [02:52<00:00,  3.12it/s]
# Training:  20%|██        | 1/5 [02:52<11:31, 172.78s/it]
# Epoch 1/5 - Training loss: 2.11
# Epoch 2 in training:   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch 2 in training:   0%|          | 1/469 [00:00<02:32,  3.07it/s]
# Epoch 2 in training:   0%|          | 2/469 [00:00<02:28,  3.15it/s]
# Epoch 2 in training:   1%|          | 3/469 [00:01<02:38,  2.94it/s]
# Epoch 2 in training:   1%|          | 4/469 [00:01<02:38,  2.93it/s]
# Epoch 2 in training:   1%|          | 5/469 [00:01<02:34,  3.01it/s]
# Epoch 2 in training:   1%|▏         | 6/469 [00:01<02:32,  3.03it/s]
# Epoch 2 in training:   1%|▏         | 7/469 [00:02<02:28,  3.10it/s]
# Epoch 2 in training:   2%|▏         | 8/469 [00:02<02:29,  3.09it/s]
# Epoch 2 in training:   2%|▏         | 9/469 [00:02<02:30,  3.06it/s]
# Epoch 2 in training:   2%|▏         | 10/469 [00:03<02:29,  3.07it/s]
# Epoch 2 in training:   2%|▏         | 11/469 [00:03<02:32,  3.00it/s]
# Epoch 2 in training:   3%|▎         | 12/469 [00:03<02:32,  3.00it/s]
# Epoch 2 in training:   3%|▎         | 13/469 [00:04<02:29,  3.06it/s]
# Epoch 2 in training:   3%|▎         | 14/469 [00:04<02:27,  3.09it/s]
# Epoch 2 in training:   3%|▎         | 15/469 [00:04<02:27,  3.07it/s]
# Epoch 2 in training:   3%|▎         | 16/469 [00:05<02:26,  3.09it/s]
# Epoch 2 in training:   4%|▎         | 17/469 [00:05<02:28,  3.04it/s]
# Epoch 2 in training:   4%|▍         | 18/469 [00:05<02:29,  3.02it/s]
# Epoch 2 in training:   4%|▍         | 19/469 [00:06<02:27,  3.06it/s]
# Epoch 2 in training:   4%|▍         | 20/469 [00:06<02:24,  3.10it/s]
# Epoch 2 in training:   4%|▍         | 21/469 [00:06<02:24,  3.10it/s]
# Epoch 2 in training:   5%|▍         | 22/469 [00:07<02:23,  3.11it/s]
# Epoch 2 in training:   5%|▍         | 23/469 [00:07<02:26,  3.04it/s]
# Epoch 2 in training:   5%|▌         | 24/469 [00:08<02:58,  2.50it/s]
# Epoch 2 in training:   5%|▌         | 25/469 [00:08<03:23,  2.18it/s]
# Epoch 2 in training:   6%|▌         | 26/469 [00:09<03:33,  2.08it/s]
# Epoch 2 in training:   6%|▌         | 27/469 [00:09<03:32,  2.08it/s]
# Epoch 2 in training:   6%|▌         | 28/469 [00:10<03:38,  2.02it/s]
# Epoch 2 in training:   6%|▌         | 29/469 [00:10<03:44,  1.96it/s]
# Epoch 2 in training:   6%|▋         | 30/469 [00:11<03:41,  1.98it/s]
# Epoch 2 in training:   7%|▋         | 31/469 [00:11<03:15,  2.23it/s]
# Epoch 2 in training:   7%|▋         | 32/469 [00:11<02:58,  2.45it/s]
# Epoch 2 in training:   7%|▋         | 33/469 [00:12<02:45,  2.63it/s]
# Epoch 2 in training:   7%|▋         | 34/469 [00:12<02:38,  2.74it/s]
# Epoch 2 in training:   7%|▋         | 35/469 [00:12<02:31,  2.87it/s]
# Epoch 2 in training:   8%|▊         | 36/469 [00:13<02:28,  2.91it/s]
# Epoch 2 in training:   8%|▊         | 37/469 [00:13<02:26,  2.95it/s]
# Epoch 2 in training:   8%|▊         | 38/469 [00:13<02:23,  3.01it/s]
# Epoch 2 in training:   8%|▊         | 39/469 [00:14<02:22,  3.01it/s]
# Epoch 2 in training:   9%|▊         | 40/469 [00:14<02:21,  3.04it/s]
# Epoch 2 in training:   9%|▊         | 41/469 [00:14<02:19,  3.08it/s]
# Epoch 2 in training:   9%|▉         | 42/469 [00:15<02:17,  3.12it/s]
# Epoch 2 in training:   9%|▉         | 43/469 [00:15<02:17,  3.10it/s]
# Epoch 2 in training:   9%|▉         | 44/469 [00:15<02:15,  3.13it/s]
# Epoch 2 in training:  10%|▉         | 45/469 [00:16<02:17,  3.09it/s]
# Epoch 2 in training:  10%|▉         | 46/469 [00:16<02:17,  3.07it/s]
# Epoch 2 in training:  10%|█         | 47/469 [00:16<02:16,  3.10it/s]
# Epoch 2 in training:  10%|█         | 48/469 [00:17<02:15,  3.11it/s]
# Epoch 2 in training:  10%|█         | 49/469 [00:17<02:13,  3.14it/s]
# Epoch 2 in training:  11%|█         | 50/469 [00:17<02:14,  3.11it/s]
# Epoch 2 in training:  11%|█         | 51/469 [00:18<02:14,  3.11it/s]
# Epoch 2 in training:  11%|█         | 52/469 [00:18<02:12,  3.15it/s]
# Epoch 2 in training:  11%|█▏        | 53/469 [00:18<02:14,  3.08it/s]
# Epoch 2 in training:  12%|█▏        | 54/469 [00:18<02:13,  3.10it/s]
# Epoch 2 in training:  12%|█▏        | 55/469 [00:19<02:11,  3.14it/s]
# Epoch 2 in training:  12%|█▏        | 56/469 [00:19<02:18,  2.97it/s]
# Epoch 2 in training:  12%|█▏        | 57/469 [00:20<02:24,  2.86it/s]
# Epoch 2 in training:  12%|█▏        | 58/469 [00:20<02:53,  2.37it/s]
# Epoch 2 in training:  13%|█▎        | 59/469 [00:21<02:56,  2.33it/s]
# Epoch 2 in training:  13%|█▎        | 60/469 [00:21<02:54,  2.35it/s]
# Epoch 2 in training:  13%|█▎        | 61/469 [00:21<02:58,  2.29it/s]
# Epoch 2 in training:  13%|█▎        | 62/469 [00:22<02:56,  2.30it/s]
# Epoch 2 in training:  13%|█▎        | 63/469 [00:22<02:56,  2.31it/s]
# Epoch 2 in training:  14%|█▎        | 64/469 [00:23<03:01,  2.23it/s]
# Epoch 2 in training:  14%|█▍        | 65/469 [00:23<03:12,  2.10it/s]
# Epoch 2 in training:  14%|█▍        | 66/469 [00:24<02:51,  2.34it/s]
# Epoch 2 in training:  14%|█▍        | 67/469 [00:24<02:38,  2.54it/s]
# Epoch 2 in training:  14%|█▍        | 68/469 [00:24<02:30,  2.67it/s]
# Epoch 2 in training:  15%|█▍        | 69/469 [00:25<02:24,  2.77it/s]
# Epoch 2 in training:  15%|█▍        | 70/469 [00:25<02:18,  2.87it/s]
# Epoch 2 in training:  15%|█▌        | 71/469 [00:25<02:16,  2.91it/s]
# Epoch 2 in training:  15%|█▌        | 72/469 [00:26<02:13,  2.97it/s]
# Epoch 2 in training:  16%|█▌        | 73/469 [00:26<02:10,  3.03it/s]
# Epoch 2 in training:  16%|█▌        | 74/469 [00:26<02:09,  3.06it/s]
# Epoch 2 in training:  16%|█▌        | 75/469 [00:27<02:09,  3.05it/s]
# Epoch 2 in training:  16%|█▌        | 76/469 [00:27<02:07,  3.07it/s]
# Epoch 2 in training:  16%|█▋        | 77/469 [00:27<02:07,  3.08it/s]
# Epoch 2 in training:  17%|█▋        | 78/469 [00:28<02:07,  3.06it/s]
# Epoch 2 in training:  17%|█▋        | 79/469 [00:28<02:05,  3.10it/s]
# Epoch 2 in training:  17%|█▋        | 80/469 [00:28<02:04,  3.13it/s]
# Epoch 2 in training:  17%|█▋        | 81/469 [00:29<02:04,  3.11it/s]
# Epoch 2 in training:  17%|█▋        | 82/469 [00:29<02:02,  3.16it/s]
# Epoch 2 in training:  18%|█▊        | 83/469 [00:29<02:02,  3.16it/s]
# Epoch 2 in training:  18%|█▊        | 84/469 [00:29<02:03,  3.11it/s]
# Epoch 2 in training:  18%|█▊        | 85/469 [00:30<02:02,  3.13it/s]
# Epoch 2 in training:  18%|█▊        | 86/469 [00:30<02:01,  3.14it/s]
# Epoch 2 in training:  19%|█▊        | 87/469 [00:30<02:00,  3.16it/s]
# Epoch 2 in training:  19%|█▉        | 88/469 [00:31<02:11,  2.89it/s]
# Epoch 2 in training:  19%|█▉        | 89/469 [00:31<02:25,  2.62it/s]
# Epoch 2 in training:  19%|█▉        | 90/469 [00:32<02:47,  2.26it/s]
# Epoch 2 in training:  19%|█▉        | 91/469 [00:32<02:40,  2.36it/s]
# Epoch 2 in training:  20%|█▉        | 92/469 [00:33<02:29,  2.52it/s]
# Epoch 2 in training:  20%|█▉        | 93/469 [00:33<02:20,  2.68it/s]
# Epoch 2 in training:  20%|██        | 94/469 [00:33<02:15,  2.78it/s]
# Epoch 2 in training:  20%|██        | 95/469 [00:34<02:23,  2.61it/s]
# Epoch 2 in training:  20%|██        | 96/469 [00:34<02:30,  2.49it/s]
# Epoch 2 in training:  21%|██        | 97/469 [00:35<02:34,  2.41it/s]
# Epoch 2 in training:  21%|██        | 98/469 [00:35<02:41,  2.30it/s]
# Epoch 2 in training:  21%|██        | 99/469 [00:36<02:47,  2.20it/s]
# Epoch 2 in training:  21%|██▏       | 100/469 [00:36<02:52,  2.14it/s]
# Epoch 2 in training:  22%|██▏       | 101/469 [00:36<02:34,  2.39it/s]
# Epoch 2 in training:  22%|██▏       | 102/469 [00:37<02:22,  2.58it/s]
# Epoch 2 in training:  22%|██▏       | 103/469 [00:37<02:16,  2.68it/s]
# Epoch 2 in training:  22%|██▏       | 104/469 [00:37<02:09,  2.81it/s]
# Epoch 2 in training:  22%|██▏       | 105/469 [00:38<02:05,  2.90it/s]
# Epoch 2 in training:  23%|██▎       | 106/469 [00:38<02:05,  2.89it/s]
# Epoch 2 in training:  23%|██▎       | 107/469 [00:38<02:02,  2.95it/s]
# Epoch 2 in training:  23%|██▎       | 108/469 [00:39<02:00,  3.00it/s]
# Epoch 2 in training:  23%|██▎       | 109/469 [00:39<02:04,  2.89it/s]
# Epoch 2 in training:  23%|██▎       | 110/469 [00:39<02:01,  2.95it/s]
# Epoch 2 in training:  24%|██▎       | 111/469 [00:40<01:58,  3.01it/s]
# Epoch 2 in training:  24%|██▍       | 112/469 [00:40<01:59,  2.98it/s]
# Epoch 2 in training:  24%|██▍       | 113/469 [00:40<01:56,  3.05it/s]
# Epoch 2 in training:  24%|██▍       | 114/469 [00:41<01:56,  3.06it/s]
# Epoch 2 in training:  25%|██▍       | 115/469 [00:41<01:56,  3.05it/s]
# Epoch 2 in training:  25%|██▍       | 116/469 [00:41<01:54,  3.07it/s]
# Epoch 2 in training:  25%|██▍       | 117/469 [00:42<02:13,  2.64it/s]
# Epoch 2 in training:  25%|██▌       | 118/469 [00:42<02:11,  2.67it/s]
# Epoch 2 in training:  25%|██▌       | 119/469 [00:42<02:07,  2.74it/s]
# Epoch 2 in training:  26%|██▌       | 120/469 [00:43<02:30,  2.32it/s]
# Epoch 2 in training:  26%|██▌       | 121/469 [00:44<02:35,  2.24it/s]
# Epoch 2 in training:  26%|██▌       | 122/469 [00:44<02:21,  2.45it/s]
# Epoch 2 in training:  26%|██▌       | 123/469 [00:44<02:13,  2.59it/s]
# Epoch 2 in training:  26%|██▋       | 124/469 [00:45<02:05,  2.74it/s]
# Epoch 2 in training:  27%|██▋       | 125/469 [00:45<02:00,  2.86it/s]
# Epoch 2 in training:  27%|██▋       | 126/469 [00:45<01:58,  2.90it/s]
# Epoch 2 in training:  27%|██▋       | 127/469 [00:45<01:57,  2.91it/s]
# Epoch 2 in training:  27%|██▋       | 128/469 [00:46<01:54,  2.98it/s]
# Epoch 2 in training:  28%|██▊       | 129/469 [00:46<02:03,  2.76it/s]
# Epoch 2 in training:  28%|██▊       | 130/469 [00:47<02:12,  2.55it/s]
# Epoch 2 in training:  28%|██▊       | 131/469 [00:47<02:16,  2.47it/s]
# Epoch 2 in training:  28%|██▊       | 132/469 [00:48<02:18,  2.44it/s]
# Epoch 2 in training:  28%|██▊       | 133/469 [00:48<02:21,  2.37it/s]
# Epoch 2 in training:  29%|██▊       | 134/469 [00:49<02:28,  2.25it/s]
# Epoch 2 in training:  29%|██▉       | 135/469 [00:49<02:23,  2.33it/s]
# Epoch 2 in training:  29%|██▉       | 136/469 [00:49<02:12,  2.51it/s]
# Epoch 2 in training:  29%|██▉       | 137/469 [00:50<02:06,  2.63it/s]
# Epoch 2 in training:  29%|██▉       | 138/469 [00:50<02:06,  2.61it/s]
# Epoch 2 in training:  30%|██▉       | 139/469 [00:50<02:00,  2.73it/s]
# Epoch 2 in training:  30%|██▉       | 140/469 [00:51<01:56,  2.83it/s]
# Epoch 2 in training:  30%|███       | 141/469 [00:51<01:54,  2.85it/s]
# Epoch 2 in training:  30%|███       | 142/469 [00:51<01:51,  2.92it/s]
# Epoch 2 in training:  30%|███       | 143/469 [00:52<01:49,  2.97it/s]
# Epoch 2 in training:  31%|███       | 144/469 [00:52<01:50,  2.95it/s]
# Epoch 2 in training:  31%|███       | 145/469 [00:52<01:47,  3.03it/s]
# Epoch 2 in training:  31%|███       | 146/469 [00:53<01:46,  3.03it/s]
# Epoch 2 in training:  31%|███▏      | 147/469 [00:53<01:45,  3.06it/s]
# Epoch 2 in training:  32%|███▏      | 148/469 [00:53<01:43,  3.11it/s]
# Epoch 2 in training:  32%|███▏      | 149/469 [00:54<01:44,  3.06it/s]
# Epoch 2 in training:  32%|███▏      | 150/469 [00:54<01:48,  2.95it/s]
# Epoch 2 in training:  32%|███▏      | 151/469 [00:54<02:08,  2.47it/s]
# Epoch 2 in training:  32%|███▏      | 152/469 [00:55<02:21,  2.25it/s]
# Epoch 2 in training:  33%|███▎      | 153/469 [00:55<02:08,  2.46it/s]
# Epoch 2 in training:  33%|███▎      | 154/469 [00:56<02:01,  2.60it/s]
# Epoch 2 in training:  33%|███▎      | 155/469 [00:56<01:53,  2.76it/s]
# Epoch 2 in training:  33%|███▎      | 156/469 [00:56<01:48,  2.87it/s]
# Epoch 2 in training:  33%|███▎      | 157/469 [00:57<01:46,  2.94it/s]
# Epoch 2 in training:  34%|███▎      | 158/469 [00:57<01:44,  2.97it/s]
# Epoch 2 in training:  34%|███▍      | 159/469 [00:57<01:42,  3.04it/s]
# Epoch 2 in training:  34%|███▍      | 160/469 [00:58<01:42,  3.02it/s]
# Epoch 2 in training:  34%|███▍      | 161/469 [00:58<01:40,  3.05it/s]
# Epoch 2 in training:  35%|███▍      | 162/469 [00:58<01:38,  3.11it/s]
# Epoch 2 in training:  35%|███▍      | 163/469 [00:59<01:37,  3.13it/s]
# Epoch 2 in training:  35%|███▍      | 164/469 [00:59<01:47,  2.84it/s]
# Epoch 2 in training:  35%|███▌      | 165/469 [00:59<01:57,  2.58it/s]
# Epoch 2 in training:  35%|███▌      | 166/469 [01:00<02:03,  2.46it/s]
# Epoch 2 in training:  36%|███▌      | 167/469 [01:00<02:03,  2.44it/s]
# Epoch 2 in training:  36%|███▌      | 168/469 [01:01<02:12,  2.26it/s]
# Epoch 2 in training:  36%|███▌      | 169/469 [01:01<02:17,  2.18it/s]
# Epoch 2 in training:  36%|███▌      | 170/469 [01:02<02:04,  2.41it/s]
# Epoch 2 in training:  36%|███▋      | 171/469 [01:02<01:56,  2.56it/s]
# Epoch 2 in training:  37%|███▋      | 172/469 [01:02<01:49,  2.72it/s]
# Epoch 2 in training:  37%|███▋      | 173/469 [01:03<01:44,  2.84it/s]
# Epoch 2 in training:  37%|███▋      | 174/469 [01:03<01:41,  2.90it/s]
# Epoch 2 in training:  37%|███▋      | 175/469 [01:03<01:39,  2.97it/s]
# Epoch 2 in training:  38%|███▊      | 176/469 [01:04<01:39,  2.95it/s]
# Epoch 2 in training:  38%|███▊      | 177/469 [01:04<01:39,  2.95it/s]
# Epoch 2 in training:  38%|███▊      | 178/469 [01:04<01:36,  3.02it/s]
# Epoch 2 in training:  38%|███▊      | 179/469 [01:05<01:34,  3.06it/s]
# Epoch 2 in training:  38%|███▊      | 180/469 [01:05<01:34,  3.05it/s]
# Epoch 2 in training:  39%|███▊      | 181/469 [01:05<01:36,  2.99it/s]
# Epoch 2 in training:  39%|███▉      | 182/469 [01:06<01:43,  2.78it/s]
# Epoch 2 in training:  39%|███▉      | 183/469 [01:06<02:02,  2.33it/s]
# Epoch 2 in training:  39%|███▉      | 184/469 [01:07<02:00,  2.36it/s]
# Epoch 2 in training:  39%|███▉      | 185/469 [01:07<01:53,  2.51it/s]
# Epoch 2 in training:  40%|███▉      | 186/469 [01:07<01:45,  2.69it/s]
# Epoch 2 in training:  40%|███▉      | 187/469 [01:08<01:40,  2.81it/s]
# Epoch 2 in training:  40%|████      | 188/469 [01:08<01:37,  2.87it/s]
# Epoch 2 in training:  40%|████      | 189/469 [01:08<01:34,  2.96it/s]
# Epoch 2 in training:  41%|████      | 190/469 [01:09<01:32,  3.01it/s]
# Epoch 2 in training:  41%|████      | 191/469 [01:09<01:31,  3.05it/s]
# Epoch 2 in training:  41%|████      | 192/469 [01:09<01:33,  2.96it/s]
# Epoch 2 in training:  41%|████      | 193/469 [01:10<01:32,  2.97it/s]
# Epoch 2 in training:  41%|████▏     | 194/469 [01:10<01:31,  3.00it/s]
# Epoch 2 in training:  42%|████▏     | 195/469 [01:10<01:32,  2.95it/s]
# Epoch 2 in training:  42%|████▏     | 196/469 [01:11<01:32,  2.97it/s]
# Epoch 2 in training:  42%|████▏     | 197/469 [01:11<01:30,  3.02it/s]
# Epoch 2 in training:  42%|████▏     | 198/469 [01:11<01:29,  3.01it/s]
# Epoch 2 in training:  42%|████▏     | 199/469 [01:12<01:40,  2.70it/s]
# Epoch 2 in training:  43%|████▎     | 200/469 [01:12<01:46,  2.52it/s]
# Epoch 2 in training:  43%|████▎     | 201/469 [01:13<01:49,  2.46it/s]
# Epoch 2 in training:  43%|████▎     | 202/469 [01:13<01:50,  2.41it/s]
# Epoch 2 in training:  43%|████▎     | 203/469 [01:14<01:58,  2.25it/s]
# Epoch 2 in training:  43%|████▎     | 204/469 [01:14<01:59,  2.22it/s]
# Epoch 2 in training:  44%|████▎     | 205/469 [01:14<01:49,  2.41it/s]
# Epoch 2 in training:  44%|████▍     | 206/469 [01:15<01:41,  2.60it/s]
# ...
# Epoch 5 in training:  53%|█████▎    | 248/469 [01:31<01:15,  2.93it/s]
# Epoch 5 in training:  53%|█████▎    | 249/469 [01:32<01:13,  3.00it/s]
# Epoch 5 in training:  53%|█████▎    | 250/469 [01:32<01:12,  3.04it/s]
# Epoch 5 in training:  54%|█████▎    | 251/469 [01:32<01:12,  3.00it/s]
# Epoch 5 in training:  54%|█████▎    | 252/469 [01:33<01:12,  3.01it/s]
# Epoch 5 in training:  54%|█████▍    | 253/469 [01:33<01:12,  3.00it/s]
# Epoch 5 in training:  54%|█████▍    | 254/469 [01:33<01:24,  2.55it/s]
# Epoch 5 in training:  54%|█████▍    | 255/469 [01:34<01:19,  2.69it/s]
# Epoch 5 in training:  55%|█████▍    | 256/469 [01:34<01:16,  2.80it/s]
# Epoch 5 in training:  55%|█████▍    | 257/469 [01:34<01:14,  2.83it/s]
# Epoch 5 in training:  55%|█████▌    | 258/469 [01:35<01:12,  2.89it/s]
# Epoch 5 in training:  55%|█████▌    | 259/469 [01:35<01:11,  2.92it/s]
# Epoch 5 in training:  55%|█████▌    | 260/469 [01:35<01:11,  2.94it/s]
# Epoch 5 in training:  56%|█████▌    | 261/469 [01:36<01:09,  2.99it/s]
# Epoch 5 in training:  56%|█████▌    | 262/469 [01:36<01:08,  3.02it/s]
# Epoch 5 in training:  56%|█████▌    | 263/469 [01:36<01:08,  3.00it/s]
# Epoch 5 in training:  56%|█████▋    | 264/469 [01:37<01:08,  3.01it/s]
# Epoch 5 in training:  57%|█████▋    | 265/469 [01:37<01:07,  3.04it/s]
# Epoch 5 in training:  57%|█████▋    | 266/469 [01:37<01:07,  3.02it/s]
# Epoch 5 in training:  57%|█████▋    | 267/469 [01:38<01:15,  2.66it/s]
# Epoch 5 in training:  57%|█████▋    | 268/469 [01:38<01:19,  2.53it/s]
# Epoch 5 in training:  57%|█████▋    | 269/469 [01:39<01:23,  2.39it/s]
# Epoch 5 in training:  58%|█████▊    | 270/469 [01:39<01:27,  2.27it/s]
# Epoch 5 in training:  58%|█████▊    | 271/469 [01:40<01:38,  2.00it/s]
# Epoch 5 in training:  58%|█████▊    | 272/469 [01:41<01:44,  1.88it/s]
# Epoch 5 in training:  58%|█████▊    | 273/469 [01:41<01:47,  1.82it/s]
# Epoch 5 in training:  58%|█████▊    | 274/469 [01:41<01:33,  2.08it/s]
# Epoch 5 in training:  59%|█████▊    | 275/469 [01:42<01:25,  2.28it/s]
# Epoch 5 in training:  59%|█████▉    | 276/469 [01:42<01:17,  2.48it/s]
# Epoch 5 in training:  59%|█████▉    | 277/469 [01:42<01:12,  2.66it/s]
# Epoch 5 in training:  59%|█████▉    | 278/469 [01:43<01:09,  2.75it/s]
# Epoch 5 in training:  59%|█████▉    | 279/469 [01:43<01:06,  2.87it/s]
# Epoch 5 in training:  60%|█████▉    | 280/469 [01:43<01:04,  2.94it/s]
# Epoch 5 in training:  60%|█████▉    | 281/469 [01:44<01:03,  2.95it/s]
# Epoch 5 in training:  60%|██████    | 282/469 [01:44<01:02,  3.00it/s]
# Epoch 5 in training:  60%|██████    | 283/469 [01:44<01:01,  3.03it/s]
# Epoch 5 in training:  61%|██████    | 284/469 [01:45<01:00,  3.04it/s]
# Epoch 5 in training:  61%|██████    | 285/469 [01:45<01:00,  3.03it/s]
# Epoch 5 in training:  61%|██████    | 286/469 [01:45<01:00,  3.05it/s]
# Epoch 5 in training:  61%|██████    | 287/469 [01:46<00:59,  3.04it/s]
# Epoch 5 in training:  61%|██████▏   | 288/469 [01:46<00:59,  3.04it/s]
# Epoch 5 in training:  62%|██████▏   | 289/469 [01:46<00:58,  3.08it/s]
# Epoch 5 in training:  62%|██████▏   | 290/469 [01:47<00:57,  3.10it/s]
# Epoch 5 in training:  62%|██████▏   | 291/469 [01:47<00:57,  3.08it/s]
# Epoch 5 in training:  62%|██████▏   | 292/469 [01:47<00:57,  3.08it/s]
# Epoch 5 in training:  62%|██████▏   | 293/469 [01:48<00:56,  3.10it/s]
# Epoch 5 in training:  63%|██████▎   | 294/469 [01:48<00:57,  3.06it/s]
# Epoch 5 in training:  63%|██████▎   | 295/469 [01:48<00:57,  3.03it/s]
# Epoch 5 in training:  63%|██████▎   | 296/469 [01:49<00:56,  3.06it/s]
# Epoch 5 in training:  63%|██████▎   | 297/469 [01:49<00:56,  3.03it/s]
# Epoch 5 in training:  64%|██████▎   | 298/469 [01:49<00:55,  3.07it/s]
# Epoch 5 in training:  64%|██████▍   | 299/469 [01:50<00:54,  3.10it/s]
# Epoch 5 in training:  64%|██████▍   | 300/469 [01:50<00:54,  3.09it/s]
# Epoch 5 in training:  64%|██████▍   | 301/469 [01:50<00:54,  3.10it/s]
# Epoch 5 in training:  64%|██████▍   | 302/469 [01:51<00:54,  3.07it/s]
# Epoch 5 in training:  65%|██████▍   | 303/469 [01:51<00:56,  2.94it/s]
# Epoch 5 in training:  65%|██████▍   | 304/469 [01:51<01:01,  2.68it/s]
# Epoch 5 in training:  65%|██████▌   | 305/469 [01:52<01:13,  2.23it/s]
# Epoch 5 in training:  65%|██████▌   | 306/469 [01:53<01:17,  2.11it/s]
# Epoch 5 in training:  65%|██████▌   | 307/469 [01:53<01:18,  2.06it/s]
# Epoch 5 in training:  66%|██████▌   | 308/469 [01:53<01:15,  2.12it/s]
# Epoch 5 in training:  66%|██████▌   | 309/469 [01:54<01:15,  2.11it/s]
# Epoch 5 in training:  66%|██████▌   | 310/469 [01:54<01:16,  2.09it/s]
# Epoch 5 in training:  66%|██████▋   | 311/469 [01:55<01:11,  2.19it/s]
# Epoch 5 in training:  67%|██████▋   | 312/469 [01:55<01:05,  2.40it/s]
# Epoch 5 in training:  67%|██████▋   | 313/469 [01:55<01:01,  2.54it/s]
# Epoch 5 in training:  67%|██████▋   | 314/469 [01:56<00:57,  2.69it/s]
# Epoch 5 in training:  67%|██████▋   | 315/469 [01:56<00:55,  2.77it/s]
# Epoch 5 in training:  67%|██████▋   | 316/469 [01:56<00:54,  2.80it/s]
# Epoch 5 in training:  68%|██████▊   | 317/469 [01:57<00:52,  2.90it/s]
# Epoch 5 in training:  68%|██████▊   | 318/469 [01:57<00:50,  2.96it/s]
# Epoch 5 in training:  68%|██████▊   | 319/469 [01:57<00:50,  2.97it/s]
# Epoch 5 in training:  68%|██████▊   | 320/469 [01:58<00:49,  3.01it/s]
# Epoch 5 in training:  68%|██████▊   | 321/469 [01:58<00:48,  3.03it/s]
# Epoch 5 in training:  69%|██████▊   | 322/469 [01:58<00:48,  3.03it/s]
# Epoch 5 in training:  69%|██████▉   | 323/469 [01:59<00:47,  3.05it/s]
# Epoch 5 in training:  69%|██████▉   | 324/469 [01:59<00:47,  3.06it/s]
# Epoch 5 in training:  69%|██████▉   | 325/469 [01:59<00:47,  3.04it/s]
# Epoch 5 in training:  70%|██████▉   | 326/469 [02:00<00:46,  3.06it/s]
# Epoch 5 in training:  70%|██████▉   | 327/469 [02:00<00:46,  3.09it/s]
# Epoch 5 in training:  70%|██████▉   | 328/469 [02:00<00:46,  3.06it/s]
# Epoch 5 in training:  70%|███████   | 329/469 [02:01<00:46,  2.98it/s]
# Epoch 5 in training:  70%|███████   | 330/469 [02:01<00:46,  3.01it/s]
# Epoch 5 in training:  71%|███████   | 331/469 [02:01<00:47,  2.89it/s]
# Epoch 5 in training:  71%|███████   | 332/469 [02:02<00:48,  2.82it/s]
# Epoch 5 in training:  71%|███████   | 333/469 [02:02<00:46,  2.89it/s]
# Epoch 5 in training:  71%|███████   | 334/469 [02:02<00:46,  2.92it/s]
# Epoch 5 in training:  71%|███████▏  | 335/469 [02:03<00:44,  2.98it/s]
# Epoch 5 in training:  72%|███████▏  | 336/469 [02:03<00:45,  2.92it/s]
# Epoch 5 in training:  72%|███████▏  | 337/469 [02:04<00:47,  2.76it/s]
# Epoch 5 in training:  72%|███████▏  | 338/469 [02:04<00:55,  2.35it/s]
# Epoch 5 in training:  72%|███████▏  | 339/469 [02:05<00:57,  2.28it/s]
# Epoch 5 in training:  72%|███████▏  | 340/469 [02:05<00:58,  2.19it/s]
# Epoch 5 in training:  73%|███████▎  | 341/469 [02:06<00:57,  2.21it/s]
# Epoch 5 in training:  73%|███████▎  | 342/469 [02:06<00:57,  2.21it/s]
# Epoch 5 in training:  73%|███████▎  | 343/469 [02:06<00:57,  2.21it/s]
# Epoch 5 in training:  73%|███████▎  | 344/469 [02:07<00:58,  2.13it/s]
# Epoch 5 in training:  74%|███████▎  | 345/469 [02:07<00:57,  2.15it/s]
# Epoch 5 in training:  74%|███████▍  | 346/469 [02:08<00:52,  2.34it/s]
# Epoch 5 in training:  74%|███████▍  | 347/469 [02:08<00:48,  2.52it/s]
# Epoch 5 in training:  74%|███████▍  | 348/469 [02:08<00:45,  2.67it/s]
# Epoch 5 in training:  74%|███████▍  | 349/469 [02:09<00:47,  2.53it/s]
# Epoch 5 in training:  75%|███████▍  | 350/469 [02:09<00:44,  2.68it/s]
# Epoch 5 in training:  75%|███████▍  | 351/469 [02:10<00:42,  2.80it/s]
# Epoch 5 in training:  75%|███████▌  | 352/469 [02:10<00:41,  2.84it/s]
# Epoch 5 in training:  75%|███████▌  | 353/469 [02:10<00:39,  2.91it/s]
# Epoch 5 in training:  75%|███████▌  | 354/469 [02:10<00:38,  2.97it/s]
# Epoch 5 in training:  76%|███████▌  | 355/469 [02:11<00:38,  2.94it/s]
# Epoch 5 in training:  76%|███████▌  | 356/469 [02:11<00:37,  2.97it/s]
# Epoch 5 in training:  76%|███████▌  | 357/469 [02:11<00:37,  3.01it/s]
# Epoch 5 in training:  76%|███████▋  | 358/469 [02:12<00:36,  3.01it/s]
# Epoch 5 in training:  77%|███████▋  | 359/469 [02:12<00:36,  3.04it/s]
# Epoch 5 in training:  77%|███████▋  | 360/469 [02:12<00:35,  3.08it/s]
# Epoch 5 in training:  77%|███████▋  | 361/469 [02:13<00:35,  3.07it/s]
# Epoch 5 in training:  77%|███████▋  | 362/469 [02:13<00:35,  3.04it/s]
# Epoch 5 in training:  77%|███████▋  | 363/469 [02:13<00:34,  3.07it/s]
# Epoch 5 in training:  78%|███████▊  | 364/469 [02:14<00:36,  2.90it/s]
# Epoch 5 in training:  78%|███████▊  | 365/469 [02:14<00:35,  2.91it/s]
# Epoch 5 in training:  78%|███████▊  | 366/469 [02:15<00:35,  2.93it/s]
# Epoch 5 in training:  78%|███████▊  | 367/469 [02:15<00:35,  2.86it/s]
# Epoch 5 in training:  78%|███████▊  | 368/469 [02:15<00:41,  2.46it/s]
# Epoch 5 in training:  79%|███████▊  | 369/469 [02:16<00:45,  2.19it/s]
# Epoch 5 in training:  79%|███████▉  | 370/469 [02:16<00:41,  2.40it/s]
# Epoch 5 in training:  79%|███████▉  | 371/469 [02:17<00:38,  2.58it/s]
# Epoch 5 in training:  79%|███████▉  | 372/469 [02:17<00:35,  2.72it/s]
# Epoch 5 in training:  80%|███████▉  | 373/469 [02:17<00:34,  2.81it/s]
# Epoch 5 in training:  80%|███████▉  | 374/469 [02:18<00:37,  2.56it/s]
# Epoch 5 in training:  80%|███████▉  | 375/469 [02:18<00:38,  2.42it/s]
# Epoch 5 in training:  80%|████████  | 376/469 [02:19<00:39,  2.36it/s]
# Epoch 5 in training:  80%|████████  | 377/469 [02:19<00:42,  2.18it/s]
# Epoch 5 in training:  81%|████████  | 378/469 [02:20<00:42,  2.12it/s]
# Epoch 5 in training:  81%|████████  | 379/469 [02:20<00:41,  2.18it/s]
# Epoch 5 in training:  81%|████████  | 380/469 [02:20<00:37,  2.38it/s]
# Epoch 5 in training:  81%|████████  | 381/469 [02:21<00:34,  2.56it/s]
# Epoch 5 in training:  81%|████████▏ | 382/469 [02:21<00:32,  2.71it/s]
# Epoch 5 in training:  82%|████████▏ | 383/469 [02:21<00:30,  2.78it/s]
# Epoch 5 in training:  82%|████████▏ | 384/469 [02:22<00:29,  2.86it/s]
# Epoch 5 in training:  82%|████████▏ | 385/469 [02:22<00:29,  2.89it/s]
# Epoch 5 in training:  82%|████████▏ | 386/469 [02:22<00:28,  2.91it/s]
# Epoch 5 in training:  83%|████████▎ | 387/469 [02:23<00:27,  2.94it/s]
# Epoch 5 in training:  83%|████████▎ | 388/469 [02:23<00:27,  2.98it/s]
# Epoch 5 in training:  83%|████████▎ | 389/469 [02:23<00:26,  3.00it/s]
# Epoch 5 in training:  83%|████████▎ | 390/469 [02:24<00:27,  2.87it/s]
# Epoch 5 in training:  83%|████████▎ | 391/469 [02:24<00:26,  2.90it/s]
# Epoch 5 in training:  84%|████████▎ | 392/469 [02:24<00:26,  2.95it/s]
# Epoch 5 in training:  84%|████████▍ | 393/469 [02:25<00:25,  2.98it/s]
# Epoch 5 in training:  84%|████████▍ | 394/469 [02:25<00:24,  3.02it/s]
# Epoch 5 in training:  84%|████████▍ | 395/469 [02:25<00:24,  3.02it/s]
# Epoch 5 in training:  84%|████████▍ | 396/469 [02:26<00:24,  2.95it/s]
# Epoch 5 in training:  85%|████████▍ | 397/469 [02:26<00:25,  2.81it/s]
# Epoch 5 in training:  85%|████████▍ | 398/469 [02:27<00:27,  2.60it/s]
# Epoch 5 in training:  85%|████████▌ | 399/469 [02:27<00:30,  2.27it/s]
# Epoch 5 in training:  85%|████████▌ | 400/469 [02:28<00:29,  2.33it/s]
# Epoch 5 in training:  86%|████████▌ | 401/469 [02:28<00:27,  2.52it/s]
# Epoch 5 in training:  86%|████████▌ | 402/469 [02:28<00:26,  2.57it/s]
# Epoch 5 in training:  86%|████████▌ | 403/469 [02:29<00:24,  2.68it/s]
# Epoch 5 in training:  86%|████████▌ | 404/469 [02:29<00:23,  2.80it/s]
# Epoch 5 in training:  86%|████████▋ | 405/469 [02:29<00:22,  2.89it/s]
# Epoch 5 in training:  87%|████████▋ | 406/469 [02:30<00:22,  2.79it/s]
# Epoch 5 in training:  87%|████████▋ | 407/469 [02:30<00:21,  2.87it/s]
# Epoch 5 in training:  87%|████████▋ | 408/469 [02:31<00:23,  2.55it/s]
# Epoch 5 in training:  87%|████████▋ | 409/469 [02:31<00:26,  2.30it/s]
# Epoch 5 in training:  87%|████████▋ | 410/469 [02:32<00:26,  2.21it/s]
# Epoch 5 in training:  88%|████████▊ | 411/469 [02:32<00:27,  2.14it/s]
# Epoch 5 in training:  88%|████████▊ | 412/469 [02:33<00:27,  2.09it/s]
# Epoch 5 in training:  88%|████████▊ | 413/469 [02:33<00:26,  2.14it/s]
# Epoch 5 in training:  88%|████████▊ | 414/469 [02:33<00:23,  2.32it/s]
# Epoch 5 in training:  88%|████████▊ | 415/469 [02:34<00:21,  2.51it/s]
# Epoch 5 in training:  89%|████████▊ | 416/469 [02:34<00:20,  2.63it/s]
# Epoch 5 in training:  89%|████████▉ | 417/469 [02:34<00:18,  2.77it/s]
# Epoch 5 in training:  89%|████████▉ | 418/469 [02:35<00:17,  2.85it/s]
# Epoch 5 in training:  89%|████████▉ | 419/469 [02:35<00:17,  2.86it/s]
# Epoch 5 in training:  90%|████████▉ | 420/469 [02:35<00:16,  2.92it/s]
# Epoch 5 in training:  90%|████████▉ | 421/469 [02:36<00:16,  2.97it/s]
# Epoch 5 in training:  90%|████████▉ | 422/469 [02:36<00:15,  2.96it/s]
# Epoch 5 in training:  90%|█████████ | 423/469 [02:36<00:15,  3.02it/s]
# Epoch 5 in training:  90%|█████████ | 424/469 [02:37<00:14,  3.06it/s]
# Epoch 5 in training:  91%|█████████ | 425/469 [02:37<00:14,  3.01it/s]
# Epoch 5 in training:  91%|█████████ | 426/469 [02:37<00:14,  3.04it/s]
# Epoch 5 in training:  91%|█████████ | 427/469 [02:38<00:15,  2.79it/s]
# Epoch 5 in training:  91%|█████████▏| 428/469 [02:38<00:16,  2.52it/s]
# Epoch 5 in training:  91%|█████████▏| 429/469 [02:39<00:17,  2.26it/s]
# Epoch 5 in training:  92%|█████████▏| 430/469 [02:39<00:16,  2.34it/s]
# Epoch 5 in training:  92%|█████████▏| 431/469 [02:39<00:15,  2.53it/s]
# Epoch 5 in training:  92%|█████████▏| 432/469 [02:40<00:13,  2.71it/s]
# Epoch 5 in training:  92%|█████████▏| 433/469 [02:40<00:12,  2.78it/s]
# Epoch 5 in training:  93%|█████████▎| 434/469 [02:40<00:12,  2.89it/s]
# Epoch 5 in training:  93%|█████████▎| 435/469 [02:41<00:11,  2.95it/s]
# Epoch 5 in training:  93%|█████████▎| 436/469 [02:41<00:11,  2.94it/s]
# Epoch 5 in training:  93%|█████████▎| 437/469 [02:41<00:10,  2.99it/s]
# Epoch 5 in training:  93%|█████████▎| 438/469 [02:42<00:10,  3.03it/s]
# Epoch 5 in training:  94%|█████████▎| 439/469 [02:42<00:10,  3.00it/s]
# Epoch 5 in training:  94%|█████████▍| 440/469 [02:42<00:09,  3.05it/s]
# Epoch 5 in training:  94%|█████████▍| 441/469 [02:43<00:09,  3.06it/s]
# Epoch 5 in training:  94%|█████████▍| 442/469 [02:43<00:10,  2.59it/s]
# Epoch 5 in training:  94%|█████████▍| 443/469 [02:44<00:10,  2.43it/s]
# Epoch 5 in training:  95%|█████████▍| 444/469 [02:44<00:10,  2.38it/s]
# Epoch 5 in training:  95%|█████████▍| 445/469 [02:45<00:10,  2.33it/s]
# Epoch 5 in training:  95%|█████████▌| 446/469 [02:45<00:10,  2.22it/s]
# Epoch 5 in training:  95%|█████████▌| 447/469 [02:46<00:09,  2.22it/s]
# Epoch 5 in training:  96%|█████████▌| 448/469 [02:46<00:08,  2.43it/s]
# Epoch 5 in training:  96%|█████████▌| 449/469 [02:46<00:07,  2.60it/s]
# Epoch 5 in training:  96%|█████████▌| 450/469 [02:47<00:07,  2.71it/s]
# Epoch 5 in training:  96%|█████████▌| 451/469 [02:47<00:06,  2.83it/s]
# Epoch 5 in training:  96%|█████████▋| 452/469 [02:47<00:05,  2.91it/s]
# Epoch 5 in training:  97%|█████████▋| 453/469 [02:47<00:05,  2.94it/s]
# Epoch 5 in training:  97%|█████████▋| 454/469 [02:48<00:05,  2.99it/s]
# Epoch 5 in training:  97%|█████████▋| 455/469 [02:48<00:04,  3.01it/s]
# Epoch 5 in training:  97%|█████████▋| 456/469 [02:48<00:04,  3.02it/s]
# Epoch 5 in training:  97%|█████████▋| 457/469 [02:49<00:03,  3.04it/s]
# Epoch 5 in training:  98%|█████████▊| 458/469 [02:49<00:03,  2.93it/s]
# Epoch 5 in training:  98%|█████████▊| 459/469 [02:50<00:03,  2.72it/s]
# Epoch 5 in training:  98%|█████████▊| 460/469 [02:50<00:03,  2.35it/s]
# Epoch 5 in training:  98%|█████████▊| 461/469 [02:51<00:03,  2.29it/s]
# Epoch 5 in training:  99%|█████████▊| 462/469 [02:51<00:02,  2.48it/s]
# Epoch 5 in training:  99%|█████████▊| 463/469 [02:51<00:02,  2.64it/s]
# Epoch 5 in training:  99%|█████████▉| 464/469 [02:52<00:01,  2.75it/s]
# Epoch 5 in training:  99%|█████████▉| 465/469 [02:52<00:01,  2.85it/s]
# Epoch 5 in training:  99%|█████████▉| 466/469 [02:52<00:01,  2.93it/s]
# Epoch 5 in training: 100%|█████████▉| 467/469 [02:53<00:00,  2.95it/s]
# Epoch 5 in training: 100%|█████████▉| 468/469 [02:53<00:00,  3.01it/s]
# Epoch 5 in training: 100%|██████████| 469/469 [02:53<00:00,  3.22it/s]
# Training: 100%|██████████| 5/5 [14:21<00:00, 172.24s/it]
# Epoch 5/5 - Training loss: 1.71
# Testing: 100%|██████████| 79/79 [00:08<00:00,  8.81it/s]
# Test loss: 1.70
# Test accuracy: 76.29%
